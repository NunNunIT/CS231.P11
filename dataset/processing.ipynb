# %% [markdown]
# # Xem kiểu dữ liệu

# %%
import json
# Xem kiểu dữ liệu
def display_json_structure(data, indent=0):
    """Recursively display the structure of a JSON object."""
    if isinstance(data, dict):
        for key, value in data.items():
            print("  " * indent + f"{key}: {type(value).__name__}")
            display_json_structure(value, indent + 1)
    elif isinstance(data, list):
        print("  " * indent + f"[List of {len(data)} {type(data[0]).__name__ if data else 'Empty'}]")
        if data:
            display_json_structure(data[0], indent + 1)

# Main function

# Load input and info data
with open('./instances_attributes_train2020.json', 'r') as file:
    data = json.load(file)

# Display structure of JSON files
print("Input JSON structure:")
display_json_structure(data)
# Out:
# Input JSON structure:
# annotations: list
#   [List of 333401 dict]
#     image_id: int
#     category_id: int
#     attribute_ids: list
#       [List of 1 int]
#     segmentation: list
#       [List of 1 list]
#         [List of 44 int]
#     bbox: list
#       [List of 4 float]
#     area: int
#     iscrowd: int
#     id: int
# images: list
#   [List of 45623 dict]
#     id: int
#     width: int
#     height: int
#     file_name: str
#     license: int
#     time_captured: str
#     original_url: str
#     isstatic: int
#     kaggle_id: str
# info: dict
#   year: int
#   version: str
#   description: str
#   contributor: str
#   url: str
#   date_created: str
# licenses: list
#   [List of 12 dict]
#     url: str
#     id: int
#     name: str
# categories: list
#   [List of 46 dict]
#     id: int
#     name: str
#     supercategory: str
#     level: int
#     taxonomy_id: str
# attributes: list
#   [List of 294 dict]
#     id: int
#     name: str
#     supercategory: str
#     level: int
#     taxonomy_id: str

# %% [markdown]
# # Thông kê từng nhãn

# %%
import json
from collections import Counter

# Đọc file JSON
with open('./instances_attributes_train2020.json', 'r') as file:
    data = json.load(file)

# Đếm số lượng theo từng category_id trong annotations
category_counts = Counter(annotation['category_id'] for annotation in data['annotations'])

# Thêm thông tin số lượng vào từng category trong categories
for category in data['categories']:
    category_id = category['id']
    count = category_counts.get(category_id, 0)
    category['count'] = count

# In ra từng category với số lượng > 5000
for category in data['categories']:
    if category['count'] > 1000:
        print(f"{category['id']} {category['name']}: {category['count']}")
# Out:
# 0 shirt, blouse: 6161
# 1 top, t-shirt, sweatshirt: 16548
# 2 sweater: 1494
# 3 cardigan: 1107
# 4 jacket: 7833
# 6 pants: 12414
# 7 shorts: 2756
# 8 skirt: 5046
# 9 coat: 3124
# 10 dress: 18739
# 13 glasses: 4855
# 14 hat: 2518
# 15 headband, head covering, hair accessory: 3470
# 16 tie: 1457
# 17 glove: 1385
# 18 watch: 3389
# 19 belt: 6851
# 21 tights, stockings: 4326
# 22 sock: 2582
# 23 shoe: 46374
# 24 bag, wallet: 7217
# 25 scarf: 1374
# 27 hood: 1226
# 28 collar: 10159
# 29 lapel: 5972
# 31 sleeve: 59448
# 32 pocket: 27179
# 33 neckline: 34258
# 34 buckle: 3300
# 35 zipper: 7991
# 36 applique: 3529
# 37 bead: 5084
# 39 flower: 1367
# 42 rivet: 4893
# 43 ruffle: 2407

# %% [markdown]
# # Lọc một số nhãn cần thiết

# %%
import json

# Đọc file JSON
with open('./instances_attributes_train2020.json', 'r') as file:
    data = json.load(file)

# Danh sách các category_id cần giữ lại
categories_to_keep = {
    0: "shirt, blouse",
    1: "top, t-shirt, sweatshirt",
    4: "jacket",
    6: "pants",
    8: "skirt",
    10: "dress",
    23: "shoe",
    24: "bag, wallet"
}

# Lọc annotations theo category_id
filtered_annotations = [
    {
        "image_id": annotation["image_id"],
        "category_id": annotation["category_id"],
        "bbox": annotation["bbox"],
        "id": annotation["id"]
    }
    for annotation in data['annotations']
    if annotation['category_id'] in categories_to_keep
]

# Lấy danh sách image_id từ filtered_annotations
image_ids_to_keep = {annotation["image_id"] for annotation in filtered_annotations}

# Lọc images theo image_id
filtered_images = [
    image
    for image in data['images']
    if image['id'] in image_ids_to_keep
]

# Lọc categories theo categories_to_keep
filtered_categories = [
    {
        "id": category["id"],
        "name": category["name"]
    }
    for category in data['categories']
    if category["id"] in categories_to_keep
]

# Tạo file JSON mới với cấu trúc yêu cầu
filtered_data = {
    "annotations": filtered_annotations,
    "images": filtered_images,
    "categories": filtered_categories
}

# Ghi file JSON mới
with open('./8-labels-cloth-classification/annotations.json', 'w') as output_file:
    json.dump(filtered_data, output_file, indent=4)

print("Trích xuất dữ liệu thành công!")
# Out:
# Trích xuất dữ liệu thành công!

# %% [markdown]
# # Chuyển mã id và chuyển định dạng dữ liệu sang dạng

# %% [markdown]
# Chuyển sang dạng
# [{
#         "imgPath": "d845a7b11a3.jpg",
#         "width": 1024,
#         "height": 685,
#         "labels": [0, 1, 1, 1, 0, 0, 1, 0],
#         "bbox": [
#             {
#                 "label": 6,
#                 "labelText": "shoe"
#                 "bbox": [minW, minH, maxW, maxH]
#             }
#         ]
# }]

# %%
import json

# Đọc file JSON đã được lọc
with open('./8-labels-cloth-classification/annotations.json', 'r') as file:
    data = json.load(file)

# Mapping category_id sang chỉ mục mới và tên
mapping = {
    0: (0, "shirt, blouse"),
    1: (1, "top, t-shirt, sweatshirt"),
    4: (2, "jacket"),
    6: (3, "pants"),
    8: (4, "skirt"),
    10: (5, "dress"),
    23: (6, "shoe"),
    24: (7, "bag, wallet")
}

# Tạo dict để tra cứu category_id -> (label, labelText)
category_mapping = {k: v for k, v in mapping.items()}

# Tạo dữ liệu mới
formatted_data = []

# Duyệt qua danh sách images
for image in data['images']:
    image_id = image['id']
    # Lọc annotations liên quan đến ảnh này
    relevant_annotations = [
        annotation for annotation in data['annotations'] if annotation['image_id'] == image_id
    ]
    
    # Tạo danh sách labels và bbox
    labels = [0] * len(mapping)  # Mặc định labels chứa toàn 0
    bbox_list = []
    
    for annotation in relevant_annotations:
        category_id = annotation['category_id']
        mapped_label, label_text = category_mapping[category_id]
        
        # Cập nhật labels
        labels[mapped_label] = 1
        
        # Chuyển bbox từ [x, y, w, h]
        x_min, y_min, w, h = annotation['bbox']
        bbox_list.append({
            "label": mapped_label,
            "labelText": label_text,
            "bbox": [x_min, y_min, w, h]
        })
    
    # Thêm thông tin ảnh vào danh sách mới
    formatted_data.append({
        "imgPath": image['file_name'],
        "width": image['width'],
        "height": image['height'],
        "labels": labels,
        "bbox": bbox_list
    })

# Ghi file JSON mới
with open('./8-labels-cloth-classification/custom.json', 'w') as output_file:
    json.dump(formatted_data, output_file, indent=4)

print("Chuyển đổi dữ liệu thành công!")
# Out:
# Chuyển đổi dữ liệu thành công!

# %% [markdown]
# # Chia tập dữ liệu

# %%
# Modified script to handle cases where images are not found in either directory
import os
import json
import shutil
import random

# Load the annotations file
annotations_file = './8-labels-cloth-classification/annotations2.json'
try:
    with open(annotations_file, 'r') as file:
        annotations = json.load(file)
except FileNotFoundError:
    raise FileNotFoundError(f"File {annotations_file} not found. Please check the path and try again.")

# Define directories
source_dirs = ["data/images", "train"]
destination_dir = './8-labels-cloth-classification/imgs'
os.makedirs(destination_dir, exist_ok=True)

# Filter, copy images, and drop annotations with missing images
filtered_annotations = []
for annotation in annotations:
    img_path = annotation['imgPath']
    found = False
    for source_dir in source_dirs:
        full_path = os.path.join(source_dir, img_path)
        if os.path.exists(full_path):
            dest_path = os.path.join(destination_dir, img_path)
            os.makedirs(os.path.dirname(dest_path), exist_ok=True)
            shutil.copy(full_path, dest_path)
            filtered_annotations.append(annotation)
            found = True
            break
    if not found:
        print(f"Image {img_path} not found in both directories. Skipping this annotation.")

# Split data into train, val, and test sets
random.shuffle(filtered_annotations)
total = len(filtered_annotations)
train_split = int(total * 0.8)
val_split = int(total * 0.1)

train_data = filtered_annotations[:train_split]
val_data = filtered_annotations[train_split:train_split + val_split]
test_data = filtered_annotations[train_split + val_split:]

# Save the splits into respective files
output_files = {
    'train': './8-labels-cloth-classification/train/data.json',
    'val': './8-labels-cloth-classification/val/data.json',
    'test': './8-labels-cloth-classification/test/data.json'
}

for split, output_file in output_files.items():
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    with open(output_file, 'w') as file:
        json.dump(eval(f"{split}_data"), file, indent=4)

len(train_data), len(val_data), len(test_data)
# Out:
# (35290, 4411, 4412)

# %% [markdown]
# # Thông kê số lượng từng nhãn trên từng tập dữ liệu

# %%
import json
from collections import Counter

def count_labels_and_images(file_path, file_path2=None):
    # Đọc dữ liệu từ file JSON đầu tiên
    with open(file_path, 'r') as file:
        data = json.load(file)

    label_counts = Counter()
    total_images = len(data)

    # Đếm số lượng từng nhãn trong file đầu tiên
    for item in data:
        for i, label in enumerate(item['labels']):
            if label == 1:  # Nếu nhãn tồn tại
                label_counts[i] += 1

    # Nếu có file thứ hai, tiếp tục đếm
    if file_path2 is not None:
        with open(file_path2, 'r') as file:
            data2 = json.load(file)
        total_images += len(data2)
        for item in data2:
            for i, label in enumerate(item['labels']):
                if label == 1:  # Nếu nhãn tồn tại
                    label_counts[i] += 1

    return total_images, label_counts

# Hàm tính tổng số lượng nhãn
def calculate_total_labels(label_counts):
    return sum(label_counts.values())

# Hàm in kết quả
def print_counts(name, images, labels):
    total_labels = calculate_total_labels(labels)
    print(f"=== {name} ===")
    print(f"Tổng số ảnh: {images}")
    print(f"Tổng số nhãn: {total_labels}")
    print("Số lượng từng nhãn (đã sắp xếp):")
    for label, count in sorted(labels.items(), key=lambda x: x[0]):
        print(f"  Label {label}: {count}")
    print()

# Đường dẫn đến các file JSON
train_file = './8-labels-cloth-classification/train/data.json'
val_file = './8-labels-cloth-classification/val/data.json'
test_file = './8-labels-cloth-classification/test/data.json'

# Đếm số lượng ảnh và nhãn
train_images, train_labels = count_labels_and_images(train_file)
val_images, val_labels = count_labels_and_images(val_file)
test_images, test_labels = count_labels_and_images(test_file)

# Tổng hợp dữ liệu từ train và val
testval_images, testval_labels = count_labels_and_images(test_file, val_file)

# In kết quả
print_counts("Train", train_images, train_labels)
print_counts("Validation", val_images, val_labels)
print_counts("Test", test_images, test_labels)
print_counts("Test + Validation", testval_images, testval_labels)
# Out:
# === Train ===
# Tổng số ảnh: 35290
# Tổng số nhãn: 77466
# Số lượng từng nhãn (đã sắp xếp):
#   Label 0: 4881
#   Label 1: 12913
#   Label 2: 6150
#   Label 3: 9879
#   Label 4: 4039
#   Label 5: 14968
#   Label 6: 19128
#   Label 7: 5508
#
# === Validation ===
# Tổng số ảnh: 4411
# Tổng số nhãn: 9713
# Số lượng từng nhãn (đã sắp xếp):
#   Label 0: 620
#   Label 1: 1624
#   Label 2: 804
#   Label 3: 1219
#   Label 4: 483
#   Label 5: 1844
#   Label 6: 2426
#   Label 7: 693
#
# === Test ===
# Tổng số ảnh: 4412
# Tổng số nhãn: 9762
# Số lượng từng nhãn (đã sắp xếp):
#   Label 0: 614
#   Label 1: 1639
#   Label 2: 788
#   Label 3: 1249
#   Label 4: 512
#   Label 5: 1854
#   Label 6: 2400
#   Label 7: 706
#
# === Test + Validation ===
# Tổng số ảnh: 8823
# Tổng số nhãn: 19475
# Số lượng từng nhãn (đã sắp xếp):
#   Label 0: 1234
#   Label 1: 3263
#   Label 2: 1592
#   Label 3: 2468
#   Label 4: 995
#   Label 5: 3698
#   Label 6: 4826
#   Label 7: 1399

# %% [markdown]
# # Tạo thư mục Image

# %%
import shutil
import json
import os
from collections import Counter, defaultdict

# Đường dẫn tới file JSON gốc và thư mục gốc
json_path = "/8-labels-cloth-classification/annotations.json"
images_dir_path = "train"

# Danh sách các categories
categories = [
    "shirt, blouse",
    "top, t-shirt, sweatshirt",
    "jacket",
    "pants",
    "skirt",
    "dress",
    "shoe",
    "bag, wallet"
]

# Thư mục để lưu các file JSON tách ra và ảnh
output_dir_ano = "./8-labels-cloth-classification/yolo/annotations"
output_dir_img = "./8-labels-cloth-classification/yolo/imgs"
os.makedirs(output_dir_ano, exist_ok=True)
os.makedirs(output_dir_img, exist_ok=True)

# Đọc file JSON gốc
with open(json_path, "r") as file:
    data = json.load(file)

# Đếm tần suất xuất hiện của mỗi `image_id`
image_id_counter = Counter(anno["image_id"] for anno in data["annotations"])

# Gom nhóm `annotations` theo `image_id`
image_id_to_annotations = defaultdict(list)
for anno in data["annotations"]:
    image_id_to_annotations[anno["image_id"]].append(anno)

# Tách annotations theo category và đảm bảo đủ 1000 phần tử
for category in categories:
    # Lọc annotations theo category
    category_annotations = [anno for anno in data["annotations"] if anno["cate"] == category]
    
    # Sắp xếp theo tần suất của `image_id`, giảm dần
    category_annotations.sort(key=lambda x: image_id_counter[x["image_id"]], reverse=True)
    
    # Chỉ chọn 1 annotation duy nhất cho mỗi `image_id` để tránh trùng lặp
    unique_annotations = {}
    for anno in category_annotations:
        if len(unique_annotations) >= 1000:
            break
        if anno["image_id"] not in unique_annotations:
            unique_annotations[anno["image_id"]] = anno

    # Nếu chưa đủ 1000 phần tử, tiếp tục thêm từ các `image_id` chưa đủ
    while len(unique_annotations) < 1000:
        for image_id, annos in image_id_to_annotations.items():
            if len(unique_annotations) >= 1000:
                break
            if image_id not in unique_annotations:
                unique_annotations[image_id] = annos[0]

    # Lấy danh sách annotations cuối cùng
    filtered_annotations = list(unique_annotations.values())
    
    # Copy ảnh và kiểm tra nếu ảnh tồn tại
    for anno in filtered_annotations:
        file_name = anno["file_name"]
        src_path = os.path.join(images_dir_path, file_name)
        
        if os.path.exists(src_path):  # Chỉ thêm nếu ảnh tồn tại
            dest_path = os.path.join(output_dir_img, file_name)
            if not os.path.exists(dest_path):  # Tránh copy lại file đã tồn tại
                shutil.copy2(src_path, dest_path)
                print(f"Đã copy: {file_name} sang {output_dir_img}")
        else:
            print(f"Ảnh không tồn tại, bỏ qua: {file_name}")
    
    count = len(filtered_annotations)  # Đếm số lượng phần tử cuối cùng
    if count > 0:
        # Ghi file JSON cho category hiện tại
        output_data = {"annotations": filtered_annotations}
        output_file = os.path.join(output_dir_ano, f"{category.replace(', ', '_').replace(' ', '_')}.json")
        with open(output_file, "w") as outfile:
            json.dump(output_data, outfile, indent=4)
        print(f"Đã tạo file JSON: {output_file} với {count} phần tử.")
    else:
        print(f"Không có dữ liệu hợp lệ cho category: {category}")
# Out:
# Ảnh không tồn tại, bỏ qua: 99f88be671d654e27e6f144f2009dfef.jpg
# Đã copy: 7d3199e21e96eb01cd92dfd96fb28841.jpg sang ./dataset_1000/imgs
# Đã copy: ce58e988f108dd47f6c137cf76378812.jpg sang ./dataset_1000/imgs
# Đã copy: 5378e5aa5d74a32e1f2824b719ceb7c8.jpg sang ./dataset_1000/imgs
# Đã copy: d6a1033585538bcae99eab1c892c4845.jpg sang ./dataset_1000/imgs
# Đã copy: 85e269e0a9e5b22123e57913bb27b2df.jpg sang ./dataset_1000/imgs
# Đã copy: 80e4eb1383efa26100280b1c465c20a3.jpg sang ./dataset_1000/imgs
# Đã copy: ba5f951394e6f52e9aef5329d756dba5.jpg sang ./dataset_1000/imgs
# Đã copy: 954c60dbdb9f497f6a0c9e8f5de47c9c.jpg sang ./dataset_1000/imgs
# Đã copy: 9dbf8b888b3a5eca34999887c1c97989.jpg sang ./dataset_1000/imgs
# Ảnh không tồn tại, bỏ qua: b62d7df7c5dc23d93efe909960dcde52.jpg
# Ảnh không tồn tại, bỏ qua: fcfa6554b1ab39dedb278e166c4742fb.jpg
# Ảnh không tồn tại, bỏ qua: 1e948adc21b8b29c3a2d0fc43c81726e.jpg
# Ảnh không tồn tại, bỏ qua: 4d77cb97f6e366b8fd7c685e78bd25d0.jpg
# Ảnh không tồn tại, bỏ qua: a0b711e99e6580db07ddb71bf2df63ae.jpg
# Ảnh không tồn tại, bỏ qua: a932fd52a2055b85eda5a91dacf6dd4b.jpg
# Đã copy: 51fb5106c0c30fc86e45cf9f33e8bf69.jpg sang ./dataset_1000/imgs
# Đã copy: ee93704434f4aa96859be27f8b04f4ca.jpg sang ./dataset_1000/imgs
# Đã copy: 4bd7e447c9ab6a97168db37926dca9a3.jpg sang ./dataset_1000/imgs
# Đã copy: b87eb766e645fcb2bb1e5e76746b67fd.jpg sang ./dataset_1000/imgs
# Đã copy: ce2c92d538944e5baccab85f4adf7b33.jpg sang ./dataset_1000/imgs
# Đã copy: 544785b63eed4512b2616f69ebe96e8f.jpg sang ./dataset_1000/imgs
# Đã copy: 4105ede0910cff801238f0e5cfa70d0c.jpg sang ./dataset_1000/imgs
# Đã copy: 3baddcb3bcebf5c838f1aad3042a2cac.jpg sang ./dataset_1000/imgs
# Đã copy: d83521be76f11fcbc8aeb60ed6e0d40e.jpg sang ./dataset_1000/imgs
# Đã copy: 994b9d16008676d273433b118a986fb2.jpg sang ./dataset_1000/imgs
# Đã copy: dee580ebfd38889510593df619bbe9b8.jpg sang ./dataset_1000/imgs
# Đã copy: fd71396788725bb988c9cd3689fcde68.jpg sang ./dataset_1000/imgs
# Đã copy: 2e6d27db1620a45fb6fca073847ef5a7.jpg sang ./dataset_1000/imgs
# Đã copy: a8c0913e58fc525ea9df1fd3fe32ac14.jpg sang ./dataset_1000/imgs
# Đã copy: cc02babfce703c513f8b3a3ec13b768a.jpg sang ./dataset_1000/imgs
# Đã copy: d627831f0a456116cd96ca2c174e9043.jpg sang ./dataset_1000/imgs
# Đã copy: 2d7509ba8f8b98434022ab417423e654.jpg sang ./dataset_1000/imgs
# Đã copy: d666ed17edced52dab119296f7b3fa4f.jpg sang ./dataset_1000/imgs
# Đã copy: 68182f68830f04c8ff33c5cd43b0a68f.jpg sang ./dataset_1000/imgs
# Đã copy: 234973f9f168588a239ec7d523c52e5d.jpg sang ./dataset_1000/imgs
# Đã copy: 3120b70f4646f1cf14a8f93f3715978d.jpg sang ./dataset_1000/imgs
# Đã copy: 1b96018754b8e8f11a8e49f4a1056211.jpg sang ./dataset_1000/imgs
# Đã copy: c9f2db53725bb5c10779a048399bb631.jpg sang ./dataset_1000/imgs
# Đã copy: a2b8b3d606ee6cae3e4ad7d299c2c308.jpg sang ./dataset_1000/imgs
# Đã copy: 9aedc9f75cb6f3958fc5c5faaa465ab1.jpg sang ./dataset_1000/imgs
# Đã copy: 6246076876a805d5ca61325925235d95.jpg sang ./dataset_1000/imgs
# Đã copy: b3bf07e4d346f1f2f9446d62d9f43605.jpg sang ./dataset_1000/imgs
# Đã copy: ee486dd0d177c55670640d377fbccd0e.jpg sang ./dataset_1000/imgs
# Đã copy: 939b46b9542a948d26fcc455c4acd1df.jpg sang ./dataset_1000/imgs
# Đã copy: 0e8691881e8f8b27b2693669ee12d046.jpg sang ./dataset_1000/imgs
# Đã copy: 9084fda7230e8cd3f483db789493eb15.jpg sang ./dataset_1000/imgs
# Đã copy: 2645d84a17aaad6df76fde13d68e2458.jpg sang ./dataset_1000/imgs
# Đã copy: 251c1ebb6b66a4b98f0636e15c174122.jpg sang ./dataset_1000/imgs
# Đã copy: da33c96b6da64e25458aa684b77d9a05.jpg sang ./dataset_1000/imgs
# Đã copy: fc46e1a14ac35522c371819b6875b4e1.jpg sang ./dataset_1000/imgs
# Đã copy: 68901bb3a19efac0cfd8cb9673232ed6.jpg sang ./dataset_1000/imgs
# Đã copy: 2a104e341af8d3e3ecc29e26e30769f8.jpg sang ./dataset_1000/imgs
# Đã copy: 6e1851e908162f3fbd5bd0ffaccdb127.jpg sang ./dataset_1000/imgs
# Đã copy: 5a94a054bd36f809d2cae0099e4fc4bd.jpg sang ./dataset_1000/imgs
# Đã copy: 49b7a84a22bc2d2fac645b4eae409b4a.jpg sang ./dataset_1000/imgs
# Đã copy: f8980b44ff51b998745ed2592c0e0842.jpg sang ./dataset_1000/imgs
# Đã copy: fb4c24847781abdb671cb6f2a1c8d889.jpg sang ./dataset_1000/imgs
# Đã copy: d81c52ce4aee31009866457929f74dfd.jpg sang ./dataset_1000/imgs
# Đã copy: 28011ec5456372787a60861c6f1098f6.jpg sang ./dataset_1000/imgs
# Đã copy: 48874b63e5f1d7043311711951cafc01.jpg sang ./dataset_1000/imgs
# Đã copy: 34d2a6056a6799e309a3e8f8a028a41c.jpg sang ./dataset_1000/imgs
# Đã copy: 01fadd6dba7d2e96e1abd377d3d6cdc0.jpg sang ./dataset_1000/imgs
# Đã copy: 82cf96c7277e9d032b0c3b915511d4a7.jpg sang ./dataset_1000/imgs
# Đã copy: 0036f906cb15e240f113184b5eed8c69.jpg sang ./dataset_1000/imgs
# Đã copy: cb9aeb24a13f24268f49764c3a1e10f4.jpg sang ./dataset_1000/imgs
# Đã copy: 2b5c2b68528034dffe0faf06cee1ec12.jpg sang ./dataset_1000/imgs
# Đã copy: fafde1c256e38ec6f563fca444e5b797.jpg sang ./dataset_1000/imgs
# Đã copy: e7e3642665116b72dd1ba4b8390238b7.jpg sang ./dataset_1000/imgs
# Đã copy: b1c6ba7eb4cf9819a3952821d7ac1cf9.jpg sang ./dataset_1000/imgs
# Đã copy: cac4d2968395074fa62e0dc9fa24a164.jpg sang ./dataset_1000/imgs
# Đã copy: 9e14374b859cfbb902604a918b62a97f.jpg sang ./dataset_1000/imgs
# Đã copy: 971aa183777df1c9ce874ec2d8abd0cf.jpg sang ./dataset_1000/imgs
# Đã copy: 916a93622906117b7418a28533b2b7ae.jpg sang ./dataset_1000/imgs
# Đã copy: 330e36c56ba8b3cb814c61759e868350.jpg sang ./dataset_1000/imgs
# Đã copy: 6a5c0933248453cae8c9eebe2de2912a.jpg sang ./dataset_1000/imgs
# Đã copy: b1c11e390ddf099e94531460cd05b2a3.jpg sang ./dataset_1000/imgs
# Đã copy: a4e507a1e642da9bed9864dd8c504fab.jpg sang ./dataset_1000/imgs
# Đã copy: 5dd58dfa16893d7923290630c890a113.jpg sang ./dataset_1000/imgs
# Đã copy: 0a67efab043e28814229781025e80983.jpg sang ./dataset_1000/imgs
# Đã copy: 6ea3e69fe5fc6d7df2e7bf995598f05b.jpg sang ./dataset_1000/imgs
# Đã copy: 1f95a45742bdb2754a9e19022be81bac.jpg sang ./dataset_1000/imgs
# Đã copy: 075161977378f06ad78ab1bf8a4f82bc.jpg sang ./dataset_1000/imgs
# Đã copy: 7ef4f448539fd996e57b9240706474ab.jpg sang ./dataset_1000/imgs
# Đã copy: 3657bb7c7ae031d92610d215bd0f4f84.jpg sang ./dataset_1000/imgs
# Đã copy: 40461dc4c059e7f5ff1f5dc368fe4748.jpg sang ./dataset_1000/imgs
# Đã copy: e1d90636cf0c9cd70a9bfa67a6938459.jpg sang ./dataset_1000/imgs
# Đã copy: 29da9486469836ab05c37e4bcf9ef1b5.jpg sang ./dataset_1000/imgs
# Đã copy: 31e44ec4afa4a206d88da429fe871264.jpg sang ./dataset_1000/imgs
# Đã copy: 3f5551c961e4e3d637f2b0697930280d.jpg sang ./dataset_1000/imgs
# Đã copy: a81beb9c5fc1433262bdece2c9128691.jpg sang ./dataset_1000/imgs
# Đã copy: e056dbe58f7878b35751276caaac4c49.jpg sang ./dataset_1000/imgs
# Đã copy: 8ae0e1afc4d5d2c76777def016941f91.jpg sang ./dataset_1000/imgs
# Đã copy: 12cdd21969745a075364b3a032f8f115.jpg sang ./dataset_1000/imgs
# Đã copy: b8271f31382c52ce397344d4c8d82ff6.jpg sang ./dataset_1000/imgs
# Đã copy: 4a21ad8161a6ebf3ee63eefba93df3d4.jpg sang ./dataset_1000/imgs
# Đã copy: 0f84261884f6c348ce48650346c6cd78.jpg sang ./dataset_1000/imgs
# Đã copy: db7debe150b74101ebeffb4ce4237a26.jpg sang ./dataset_1000/imgs
# Đã copy: bd37c8fd4f575668f3188668f5e5e607.jpg sang ./dataset_1000/imgs
# Đã copy: e18be33530beee486dc4d60b1488a474.jpg sang ./dataset_1000/imgs
# Đã copy: 9b58c45a0844dc4fbc714e125657dbc7.jpg sang ./dataset_1000/imgs
# Đã copy: a4618e2bad7d559155f36c2555269fef.jpg sang ./dataset_1000/imgs
# Đã copy: f7e3fc36f314e69314446efe29e0d047.jpg sang ./dataset_1000/imgs
# Đã copy: f369880af782cbd14aeef2749848c58f.jpg sang ./dataset_1000/imgs
# Đã copy: a1caf8b1220e2b936da1a300e3287b4e.jpg sang ./dataset_1000/imgs
# Đã copy: 36577c8111ac1ffd27020170e846950e.jpg sang ./dataset_1000/imgs
# Đã copy: 0661c8705bb3bfda67b59841e8e86662.jpg sang ./dataset_1000/imgs
# Đã copy: d794999cd45867637254807d36605cb3.jpg sang ./dataset_1000/imgs
# Đã copy: c7a4a3801f6838098e0d1efd2e460264.jpg sang ./dataset_1000/imgs
# Đã copy: ea7bf988cbb013c462af56f6ad201e75.jpg sang ./dataset_1000/imgs
# Đã copy: e45e76a61a29b20e66c2b4389597b8cf.jpg sang ./dataset_1000/imgs
# Đã copy: 060aeaca3c67b042f61f729fa75fe901.jpg sang ./dataset_1000/imgs
# Đã copy: 29e0b791a4203d2009229be06ae7de68.jpg sang ./dataset_1000/imgs
# Đã copy: 81df17f6864a29dccb6668cf16ebd589.jpg sang ./dataset_1000/imgs
# Đã copy: ed4285f6ae780f5307f7631791ad7e35.jpg sang ./dataset_1000/imgs
# Đã copy: f03cc17d75784e75bf104f5986462bc8.jpg sang ./dataset_1000/imgs
# Ảnh không tồn tại, bỏ qua: 70aebd85d46acd38cf52bcdfe49c2804.jpg
# Ảnh không tồn tại, bỏ qua: 19ad42297510e1e44cd467186f702f7b.jpg
# Ảnh không tồn tại, bỏ qua: 6995bedc0113de65175045345accc965.jpg
# Ảnh không tồn tại, bỏ qua: 3039207a00b5b0703390c78433d8d60f.jpg
# Ảnh không tồn tại, bỏ qua: e6ba2f781bd35ce63e01f774948de028.jpg
# Ảnh không tồn tại, bỏ qua: 7009b641d8331f4abb7544c4633b1721.jpg
# Ảnh không tồn tại, bỏ qua: 2549b851b6ce01d842c85c00f6b64d6f.jpg
# Ảnh không tồn tại, bỏ qua: 9f18695e8b4ae73b8ba007802c882598.jpg
# Ảnh không tồn tại, bỏ qua: bcbf81eb9fedf9160e508f3eabb42a72.jpg
# Ảnh không tồn tại, bỏ qua: 62a91f891db700449eb56491718b4b43.jpg
# Ảnh không tồn tại, bỏ qua: 736527f6305364e7e74c5b3c1ac6caf6.jpg
# Ảnh không tồn tại, bỏ qua: 5b06b65f203d06fc9c50e804f4f8aa25.jpg
# Ảnh không tồn tại, bỏ qua: bdff74cea3005c9ac1d06ba7a68611e5.jpg
# Ảnh không tồn tại, bỏ qua: 5cda8e9dd8ab6377e460c92fa2c23c80.jpg
# Ảnh không tồn tại, bỏ qua: 6cd4f7de2692638847746496c3278182.jpg
# Ảnh không tồn tại, bỏ qua: 7ef52ba6e7f3d10ab1d02b70f1394f8c.jpg
# Ảnh không tồn tại, bỏ qua: ec137052c7ab1b83eb722b05f47b98bd.jpg
# Ảnh không tồn tại, bỏ qua: 82d99ea197515e16666492102606df9b.jpg
# Ảnh không tồn tại, bỏ qua: 238d98533f882cfbe316d25452c92d28.jpg
# Ảnh không tồn tại, bỏ qua: ed0f1471740fd69fb289f56ef8a09886.jpg
# Ảnh không tồn tại, bỏ qua: 59bb105316ba96b43ed56d5952ce4555.jpg
# Ảnh không tồn tại, bỏ qua: fcc57bfaf8325e89600281461f74a2ec.jpg
# Ảnh không tồn tại, bỏ qua: d8db8088b197516cc649127a251b92b3.jpg
# Ảnh không tồn tại, bỏ qua: d59b62b3f00920b84e91a2d606a7274a.jpg
# Ảnh không tồn tại, bỏ qua: 9472b3344c25bcec306233638ce1a8ab.jpg
# Ảnh không tồn tại, bỏ qua: 42ce1c475d64a3249c87e87576f47e3c.jpg
# Ảnh không tồn tại, bỏ qua: 67dc007768095e1cbdfcfbc439b97885.jpg
# Ảnh không tồn tại, bỏ qua: 173da5c192cb7341e2f69eba37ffc959.jpg
# Ảnh không tồn tại, bỏ qua: 10f12310bbf164990c8806d71cbdb9e3.jpg
# Ảnh không tồn tại, bỏ qua: 6e0bd328dccf71859305770ef34f5570.jpg
# Ảnh không tồn tại, bỏ qua: ca84bd085d48d071d3c309da30306962.jpg
# Ảnh không tồn tại, bỏ qua: c6267096df243076b47575415f0ceb0c.jpg
# Ảnh không tồn tại, bỏ qua: 86f6bd0aed387f0ca3616fab47d26dd7.jpg
# Ảnh không tồn tại, bỏ qua: 2ceb4715f2b4df7428eee6fb6409887f.jpg
# Ảnh không tồn tại, bỏ qua: 71baca61409af5fd012c9810dca8992b.jpg
# Ảnh không tồn tại, bỏ qua: f205bb1a8952487440eee9d423c28a94.jpg
# Ảnh không tồn tại, bỏ qua: 1f601d25e5d1194bd423e65bb7abeff8.jpg
# Ảnh không tồn tại, bỏ qua: 8fa881a0e6401e1c8c4e8a15b3fb556d.jpg
# Ảnh không tồn tại, bỏ qua: 09ba85cb7d9b326be5dc9872be88790b.jpg
# Ảnh không tồn tại, bỏ qua: ddd927cd4db78a4bc14885638450989e.jpg
# Ảnh không tồn tại, bỏ qua: b21b45507272695ea242ad78d56afd42.jpg
# Ảnh không tồn tại, bỏ qua: a0473742d7f8678b76e362494dbd4bc6.jpg
# Ảnh không tồn tại, bỏ qua: aee62ed518afca486dc06a3fc3d4f1f1.jpg
# Ảnh không tồn tại, bỏ qua: 1abc78f5d4774fee9646701a9efd7562.jpg
# Ảnh không tồn tại, bỏ qua: 5c65b0b193423df496da3dfb9329fcd8.jpg
# Ảnh không tồn tại, bỏ qua: 05066a615dd5fb32b255f8f5df40f0ca.jpg
# Ảnh không tồn tại, bỏ qua: f48693cbb8edb1b6357509edc113176b.jpg
# Ảnh không tồn tại, bỏ qua: 7058cf6083ba8bbff2feff2bbfd85fcb.jpg
# Ảnh không tồn tại, bỏ qua: d42b1a5bb4b7a80c86b4c920f2ec0163.jpg
# Ảnh không tồn tại, bỏ qua: 58e58aa81e823f49a356b634bd9a24cc.jpg
# Ảnh không tồn tại, bỏ qua: dbd64d4a22c5ea0a5e60db02b6cc72e3.jpg
# Ảnh không tồn tại, bỏ qua: 731a2a2d476e4790a69ca2b3e35e8b74.jpg
# Ảnh không tồn tại, bỏ qua: 3c82d05690fb09e0e16c8bb502bdfd1c.jpg
# Ảnh không tồn tại, bỏ qua: 11568f426badbdc092ac17da5ea42f19.jpg
# Ảnh không tồn tại, bỏ qua: ceea006d5b4892310ed8c9372aa2518a.jpg
# Ảnh không tồn tại, bỏ qua: dc33298a0d9abbf01403b2c12b6ebd47.jpg
# Ảnh không tồn tại, bỏ qua: 860e2108db41eef620e55c3d0ece12bd.jpg
# Ảnh không tồn tại, bỏ qua: 3d7fdabde2ae9e536690d162d2292aef.jpg
# Ảnh không tồn tại, bỏ qua: 11f464062db52bfcd96177aadfb0352d.jpg
# Ảnh không tồn tại, bỏ qua: f2a76680ee4120c91b10e01c4891ab94.jpg
# Ảnh không tồn tại, bỏ qua: f5f15fde94650b49c19b1108e7baacaa.jpg
# Ảnh không tồn tại, bỏ qua: f4695def4594a07d59d2a35967614129.jpg
# Ảnh không tồn tại, bỏ qua: 409d0263a72abdad2af97d85131f9761.jpg
# Ảnh không tồn tại, bỏ qua: 3038e459aa8b1d417e669af3da31f036.jpg
# Ảnh không tồn tại, bỏ qua: 91065bd3ce713294acc17cc4f4f9bc41.jpg
# Ảnh không tồn tại, bỏ qua: 8dc9ae24169c3389d94680c813ad66dc.jpg
# Ảnh không tồn tại, bỏ qua: f6aa4535f41a715fdf249943691e289d.jpg
# Ảnh không tồn tại, bỏ qua: 0f1d90f8a44d714d8c644a4514a8ab5f.jpg
# Ảnh không tồn tại, bỏ qua: b6669b3ba8b6e30d69b2feb809caa32c.jpg
# Ảnh không tồn tại, bỏ qua: 0d83990810fd0923e9c35dd181a45ee0.jpg
# Ảnh không tồn tại, bỏ qua: ba3bbd072bf67724461ae89c2368c8be.jpg
# Ảnh không tồn tại, bỏ qua: bd17ba6e9208c9d8196130df06b22b9c.jpg
# Ảnh không tồn tại, bỏ qua: 3168996719d4402998ae3fd627d490c7.jpg
# Ảnh không tồn tại, bỏ qua: 2b52a837295e4f92e79b826a2cc7735d.jpg
# Ảnh không tồn tại, bỏ qua: 626ff446472f7246508c5da977605f10.jpg
# Ảnh không tồn tại, bỏ qua: 60e04ab87074a9442a6bd972dc7d7270.jpg
# Ảnh không tồn tại, bỏ qua: 41d6a16eb07a3d981422a7e6bbbb325e.jpg
# Ảnh không tồn tại, bỏ qua: 7f6924ad6958d10a77bdf3b348ad18a0.jpg
# Ảnh không tồn tại, bỏ qua: 7f7a1df7ac9c8a5ef260419d53b2b983.jpg
# Ảnh không tồn tại, bỏ qua: a73717ac5ab53a45b149ef01b552133f.jpg
# Ảnh không tồn tại, bỏ qua: 886bf74258436e1f8257fc35e93026a5.jpg
# Ảnh không tồn tại, bỏ qua: 0b062f8818eb85a797a288e463da87cd.jpg
# Ảnh không tồn tại, bỏ qua: 12befe9e6142edd245e5fd910e2894c0.jpg
# Ảnh không tồn tại, bỏ qua: 8ab9e80772538175c96c70d9aeaceb1e.jpg
# Ảnh không tồn tại, bỏ qua: e2474eb8a4648c18ce191d1a5388c0ba.jpg
# Ảnh không tồn tại, bỏ qua: 15b5c8e294c2cd1e4ba56ca36ef42428.jpg
# Ảnh không tồn tại, bỏ qua: 9684681e29ce0d37c937e51f85773479.jpg
# Ảnh không tồn tại, bỏ qua: 991a1adea3e0182d598dfa653680917d.jpg
# Ảnh không tồn tại, bỏ qua: 360a5e826ccd4f45ae2c18048894b3be.jpg
# Ảnh không tồn tại, bỏ qua: 8db40b9f0e9834b4f23bdbdb66f25115.jpg
# Ảnh không tồn tại, bỏ qua: 34abefde4f03c8bd8d69e72c39e63b40.jpg
# Ảnh không tồn tại, bỏ qua: c9deb0adb3c4f5bdd6d9668464db9692.jpg
# Ảnh không tồn tại, bỏ qua: 175f9e76786319a39350b50512d9a256.jpg
# Ảnh không tồn tại, bỏ qua: 54cd3b67664eb428d31d607622c99861.jpg
# Ảnh không tồn tại, bỏ qua: 6317834e117b3a7e9669f1cf23f36087.jpg
# Ảnh không tồn tại, bỏ qua: 72ccb960fe82de11b0c86e85c1dd924a.jpg
# Ảnh không tồn tại, bỏ qua: 782c726ca40b6a9149729ce627a6dc82.jpg
# Ảnh không tồn tại, bỏ qua: 12297102305386eeed7575d577b333d0.jpg
# Ảnh không tồn tại, bỏ qua: 7c41c85ee9524f8f34df13f84e837705.jpg
# Ảnh không tồn tại, bỏ qua: dfbbb56d2510f50cb248080edb6ab013.jpg
# Ảnh không tồn tại, bỏ qua: 84cd013bab1cf7a55a347dd52951114d.jpg
# Ảnh không tồn tại, bỏ qua: 5faedda80337c5d5cd26ee385b80aa17.jpg
# Ảnh không tồn tại, bỏ qua: f5675eafa482d67b7493d2bc27bc5709.jpg
# Ảnh không tồn tại, bỏ qua: d4c40a8fba2a27a6964b5a3bde178243.jpg
# Ảnh không tồn tại, bỏ qua: 7bd13b3beafc3bd8a657ef608dbf3aae.jpg
# Ảnh không tồn tại, bỏ qua: e5a3aa7a41ef0eefe2c940644f13aa59.jpg
# Ảnh không tồn tại, bỏ qua: ee9afc0809f5de2116600ea6c3e4d30e.jpg
# Ảnh không tồn tại, bỏ qua: d192ee8bf689fe30815676030f53632f.jpg
# Ảnh không tồn tại, bỏ qua: 705f503b5ef785f798951908695bdcb1.jpg
# Ảnh không tồn tại, bỏ qua: f157d837f4d18c124c2c2f17b267f76d.jpg
# Ảnh không tồn tại, bỏ qua: d4e314e36f1e4988c90c1e6bbfcbb22c.jpg
# Ảnh không tồn tại, bỏ qua: 55c167fe224d16dd9c4954ee6afe2b08.jpg
# Ảnh không tồn tại, bỏ qua: a20a1c144032ec38c00201c5feb73c9d.jpg
# Ảnh không tồn tại, bỏ qua: ad5b3b2eeb9d4fe2d5c63fe1318f5c37.jpg
# Ảnh không tồn tại, bỏ qua: d16968a7c8af1bcf3644624b89a6b32c.jpg
# Ảnh không tồn tại, bỏ qua: cff4316e8c3f275e3ecb63a6c3d12409.jpg
# Ảnh không tồn tại, bỏ qua: 26f43c482c880c433a0b5791db35f88e.jpg
# Ảnh không tồn tại, bỏ qua: 2e572e4b7b351668026c844284479d0d.jpg
# Ảnh không tồn tại, bỏ qua: c3a074e4ff42e180b39e6abf1bd15157.jpg
# Ảnh không tồn tại, bỏ qua: 66fea8279cb8ee0fd525ee98a558a32a.jpg
# Ảnh không tồn tại, bỏ qua: 8dc705a9fa2023d3f932aba081f32b32.jpg
# Ảnh không tồn tại, bỏ qua: e1371e430ca8971cecd6a8e0bdb7cabe.jpg
# Ảnh không tồn tại, bỏ qua: 6bbdae6bb5d7c18c3ac39dfd52cad023.jpg
# Ảnh không tồn tại, bỏ qua: a8dd40fdaa0ae48066641d52a3b3c561.jpg
# Ảnh không tồn tại, bỏ qua: 8abe5b1bea8c88e86ec92bdd327bff8d.jpg
# Ảnh không tồn tại, bỏ qua: 989082aa8c6cd1f2b3754ee732b28d8d.jpg
# Ảnh không tồn tại, bỏ qua: 35d5a45298ad70b29cdfc5792555bb26.jpg
# Ảnh không tồn tại, bỏ qua: 17bc92170312f252018e54feba774312.jpg
# Ảnh không tồn tại, bỏ qua: c99bb635773c9ada320ad293ff75b4f5.jpg
# Ảnh không tồn tại, bỏ qua: 65e0757d9080c021008b33f2de80ad66.jpg
# Ảnh không tồn tại, bỏ qua: 75435777fb693fc7a1aeca4f3fae4f99.jpg
# Ảnh không tồn tại, bỏ qua: 1fe30e5c7660e95fc573bac839ddcf81.jpg
# Ảnh không tồn tại, bỏ qua: 85a1a761e51b3106934640d1e00a9f68.jpg
# Ảnh không tồn tại, bỏ qua: 7495abfee01e8461154ffd7cf320683f.jpg
# Ảnh không tồn tại, bỏ qua: f241d5d9463a04b5b7fb4f87f38dec19.jpg
# Ảnh không tồn tại, bỏ qua: e70b8f25678acd91acf4df90adacaa0b.jpg
# Ảnh không tồn tại, bỏ qua: 942791df4968074965ee1801609354a9.jpg
# Ảnh không tồn tại, bỏ qua: 3227643c46b1775dca205ed4cfbc49fe.jpg
# Ảnh không tồn tại, bỏ qua: 8294f615103ba13d9430e4d8cb7aa092.jpg
# Ảnh không tồn tại, bỏ qua: 920767dc59cdf092a6b6d54ee5094672.jpg
# Ảnh không tồn tại, bỏ qua: 4426b711b273abf781ed47775762b4a0.jpg
# Ảnh không tồn tại, bỏ qua: d25e3c438205313278fee69dd5dffdad.jpg
# Ảnh không tồn tại, bỏ qua: 983ae5f31bb09fd635c0b714b8b76329.jpg
# Ảnh không tồn tại, bỏ qua: fa0fbef33e04b1402f861f0628c755b2.jpg
# Ảnh không tồn tại, bỏ qua: 3cbf846b292f9446b21a0ac965f32c25.jpg
# Ảnh không tồn tại, bỏ qua: 6f30324b2dda51babfa0d38add49d6de.jpg
# Ảnh không tồn tại, bỏ qua: 6641f6cb8018d41efbfe52307a2245f2.jpg
# Ảnh không tồn tại, bỏ qua: 6e57acafad78ef1eaac69dd2f51295fb.jpg
# Ảnh không tồn tại, bỏ qua: 297ea597f7dfa6d710b2e8176cb3b913.jpg
# Ảnh không tồn tại, bỏ qua: b9bd6b78b93d71100616914659c79d32.jpg
# Ảnh không tồn tại, bỏ qua: a96775c3596fed1b9e2beed86f8e2de8.jpg
# Ảnh không tồn tại, bỏ qua: 506384065789d26b7536672e60514b6a.jpg
# Ảnh không tồn tại, bỏ qua: a1f403eefea6738d9f9c3020cffe8bbe.jpg
# Ảnh không tồn tại, bỏ qua: 8cce0d5231e84b327500d8aadf094a22.jpg
# Ảnh không tồn tại, bỏ qua: edf77d20318aabff2ac8dd6460f3c0fc.jpg
# Ảnh không tồn tại, bỏ qua: ba2faa58092809e759c3b9f3eab66431.jpg
# Ảnh không tồn tại, bỏ qua: 24889cc2a86edb1bedcb118ef494062c.jpg
# Ảnh không tồn tại, bỏ qua: 8c543c41a9c5ea0aedf6597504c706c6.jpg
# Ảnh không tồn tại, bỏ qua: 958290d7df8b2a4b642f5a02224958ba.jpg
# Ảnh không tồn tại, bỏ qua: 4f331a441150ef81cec5879e73aa9761.jpg
# Ảnh không tồn tại, bỏ qua: 476afd7183381f28ea4df875fe0a1215.jpg
# Ảnh không tồn tại, bỏ qua: 9501d3a576e6500c73dc77057aa78b16.jpg
# Ảnh không tồn tại, bỏ qua: 3a7581726d48c8fa69ee2498e8da7a4c.jpg
# Ảnh không tồn tại, bỏ qua: c961f9dd97289f84c157799f660e33a9.jpg
# Ảnh không tồn tại, bỏ qua: 2f18aaab685a98876504a0f32d4c1d8e.jpg
# Ảnh không tồn tại, bỏ qua: e86927afde98f97675780c015630b7d6.jpg
# Ảnh không tồn tại, bỏ qua: d84445a935f38ea47b0164b987790b3c.jpg
# Đã copy: 75f213fc1067ce628166efbc67733629.jpg sang ./dataset_1000/imgs
# Đã copy: 2ae4e3b9bd82819f4a0a46b09554b0ae.jpg sang ./dataset_1000/imgs
# Đã copy: 9edd83f2c6dde68fd6adec4b277154bc.jpg sang ./dataset_1000/imgs
# Đã copy: 7bb7f5eba4ed4eb78927486e048cb64d.jpg sang ./dataset_1000/imgs
# Đã copy: d1d777e9d7c06b95878bc44ae1352ad0.jpg sang ./dataset_1000/imgs
# Đã copy: 47bfd995528f36044e84949133519957.jpg sang ./dataset_1000/imgs
# Đã copy: ef9ce5942d25cd35da60e953b9318411.jpg sang ./dataset_1000/imgs
# Đã copy: ee12e7e4c10e8229b6269625fdb75a20.jpg sang ./dataset_1000/imgs
# Đã copy: 601d2e72d358bb431ec711f3adaeff45.jpg sang ./dataset_1000/imgs
# Đã copy: d530136387782390c351cc3921b0a380.jpg sang ./dataset_1000/imgs
# Đã copy: dd046e7f3a25093b301651cb6d42b737.jpg sang ./dataset_1000/imgs
# Đã copy: e66d46106e1b24e0a8160b3615394d33.jpg sang ./dataset_1000/imgs
# Đã copy: 95081e40ab7fdbc2b95b5db79011430b.jpg sang ./dataset_1000/imgs
# Đã copy: bbc29b6085ccb9fbf76537dbf38eb172.jpg sang ./dataset_1000/imgs
# Đã copy: f6913caa3c66a906611cd76004dc0e89.jpg sang ./dataset_1000/imgs
# Đã copy: 7b375d7d3a21c68259fd1e07bb049814.jpg sang ./dataset_1000/imgs
# Đã copy: 3a7cd86a5f0d4cebf16cbaba893a04cb.jpg sang ./dataset_1000/imgs
# Đã copy: f6d5d0f2366f6a4447aac750226ac6c4.jpg sang ./dataset_1000/imgs
# Đã copy: 75dc6e195790b476cbcb1ac673b7e937.jpg sang ./dataset_1000/imgs
# Đã copy: baf2afe0ebc6a1dac4d46332af5ff1ff.jpg sang ./dataset_1000/imgs
# Đã copy: cb46b2702fba4d32f9157fd7932fe96d.jpg sang ./dataset_1000/imgs
# Đã copy: d9bb84d18b6d9d6516b1637af7716d3b.jpg sang ./dataset_1000/imgs
# Đã copy: da5e3fa036c0425077164d58b2d47e45.jpg sang ./dataset_1000/imgs
# Đã copy: 40dae1e83e280081fca2f3c1d2dc6baf.jpg sang ./dataset_1000/imgs
# Đã copy: 5d62dab549299f0c9790faf48a46f9eb.jpg sang ./dataset_1000/imgs
# Đã copy: 3a55e68c7410897a69ca3ca8aefa2e36.jpg sang ./dataset_1000/imgs
# Đã copy: 2bbdb32abd89f43819571bf18cf65aae.jpg sang ./dataset_1000/imgs
# Đã copy: ac134a34f491394ac2cc69b48df568b2.jpg sang ./dataset_1000/imgs
# Đã copy: 3603bbd9b45191ed0402c3cd542aae1d.jpg sang ./dataset_1000/imgs
# Đã copy: d02812074989b435be70dfd4f4ac1ed0.jpg sang ./dataset_1000/imgs
# Đã copy: 763113602b08fedcd9a0ba12b22a7999.jpg sang ./dataset_1000/imgs
# Đã copy: cbad02f573766cfc726a66a2c85551b0.jpg sang ./dataset_1000/imgs
# Đã copy: 1b62ef30df6df411ff7a2fdffb574244.jpg sang ./dataset_1000/imgs
# Đã copy: 8fb6acea6bdf22158b567e6b832a83b3.jpg sang ./dataset_1000/imgs
# Đã copy: 1817b93b2a6ab6e19ff7906f61aa08f7.jpg sang ./dataset_1000/imgs
# Đã copy: b56ab3fa01dc4d8a8b73a7adcedc2dbc.jpg sang ./dataset_1000/imgs
# Đã copy: 0b6d006caf77034fc4e5a65de1323ba9.jpg sang ./dataset_1000/imgs
# Đã copy: 03c1085b49b6d7dd63084a96648f7fea.jpg sang ./dataset_1000/imgs
# Đã copy: 14c2ffcd47505f4a9c555a74366afe47.jpg sang ./dataset_1000/imgs
# Đã copy: 90702667c9fda1e830ff236961ce73a6.jpg sang ./dataset_1000/imgs
# Đã copy: 7972c308139e678f7dc07602c44534e5.jpg sang ./dataset_1000/imgs
# Đã copy: d16e3ebd0af128118d94c127be6930bd.jpg sang ./dataset_1000/imgs
# Đã copy: 96ac2a691f77f46b377a24da856e6f39.jpg sang ./dataset_1000/imgs
# Đã copy: f7b8c3b44903f0bdc7946cfcb962854e.jpg sang ./dataset_1000/imgs
# Đã copy: 11e9e732beab03c452a0cd6da35fbfb6.jpg sang ./dataset_1000/imgs
# Đã copy: 34c9cfdc8bdf05cf1be40fd578336a87.jpg sang ./dataset_1000/imgs
# Đã copy: 82e705b916e371aafb7e0b87eea222bc.jpg sang ./dataset_1000/imgs
# Đã copy: 597cb61e51be1f39fa6532d4fc40f0f9.jpg sang ./dataset_1000/imgs
# Đã copy: 8db1c883f84e525c6da74cce64b1d3ec.jpg sang ./dataset_1000/imgs
# Đã copy: b8ad44f97f2aee729086d718ba333f12.jpg sang ./dataset_1000/imgs
# Đã copy: bf669a7215fd5e54908e204bb82ff8a3.jpg sang ./dataset_1000/imgs
# Đã copy: 20e26183417bebe58bb6dd4a45d076bf.jpg sang ./dataset_1000/imgs
# Đã copy: f3f0e17af1bf95e9a5e57def038a65e4.jpg sang ./dataset_1000/imgs
# Đã copy: 57164ed3235e99ca0ed18cb4bdad1ce2.jpg sang ./dataset_1000/imgs
# Đã copy: de9d83dcdfd8e312b0ff184979d3b414.jpg sang ./dataset_1000/imgs
# Đã copy: c791314cbf930c9bd6a4adb06305a4d3.jpg sang ./dataset_1000/imgs
# Đã copy: d31edab5a2a7f471ddd882de5ea8012c.jpg sang ./dataset_1000/imgs
# Đã copy: be07003a0d55117fb803dd1e9c41b01f.jpg sang ./dataset_1000/imgs
# Đã copy: aca685bf94f72676c77dafc110106d05.jpg sang ./dataset_1000/imgs
# Đã copy: 275864f6fb6d9d257cf55e0d5a36f4b5.jpg sang ./dataset_1000/imgs
# Đã copy: 3d76e096ec3fbd4797953af47bdf4c0a.jpg sang ./dataset_1000/imgs
# Đã copy: ade007f9a5ded83d716ce25c2e8cc754.jpg sang ./dataset_1000/imgs
# Đã copy: eeb809724184d0e32512df317f262860.jpg sang ./dataset_1000/imgs
# Đã copy: 84ecbec52c1460091e574bbd89f27456.jpg sang ./dataset_1000/imgs
# Đã copy: 824b05629c93ac19ccbfc734d62f3358.jpg sang ./dataset_1000/imgs
# Đã copy: 5114d541929484f0af4c7c17a7cd5467.jpg sang ./dataset_1000/imgs
# Đã copy: 695c0e505b82478afe7fdd19a5777286.jpg sang ./dataset_1000/imgs
# Đã copy: 6ea161df6add75b924b3876bb990d85c.jpg sang ./dataset_1000/imgs
# Đã copy: 90bb5a1b4498670201e0d3420ef11639.jpg sang ./dataset_1000/imgs
# Đã copy: b93dfd8ce32bb813c427101350f2998c.jpg sang ./dataset_1000/imgs
# Đã copy: b1c6e9a4acf9f0b3b11ba4d4dcffff65.jpg sang ./dataset_1000/imgs
# Đã copy: 52cdd90303436c59f83b03b2caea86ea.jpg sang ./dataset_1000/imgs
# Đã copy: e04ea2094c8a4994411f0de2bf46ff12.jpg sang ./dataset_1000/imgs
# Đã copy: 058f5d11f617345379e32822aa9e769d.jpg sang ./dataset_1000/imgs
# Đã copy: 617bb988ed3c326993eab0ee4ef17ea9.jpg sang ./dataset_1000/imgs
# Đã copy: 96486ac12b3a31ecfe95e0bf8337c1cf.jpg sang ./dataset_1000/imgs
# Đã copy: 940f01b146d2e0f74192af9584ffa692.jpg sang ./dataset_1000/imgs
# Đã copy: b48c9dc38933b70d518a0ef396b23fa7.jpg sang ./dataset_1000/imgs
# Đã copy: dc74ec77bc62baf69e9d529eb6057cc3.jpg sang ./dataset_1000/imgs
# Đã copy: 00000663ed1ff0c4e0132b9b9ac53f6e.jpg sang ./dataset_1000/imgs
# Đã copy: 03a832041ef9b6872a576e7bd87badb0.jpg sang ./dataset_1000/imgs
# Đã copy: b98549b4697def558e1a549a829b97a3.jpg sang ./dataset_1000/imgs
# Đã copy: 0d12fb12f301777c0f5038521399a262.jpg sang ./dataset_1000/imgs
# Đã copy: 1639409ee3e990b47c592688f56a0c40.jpg sang ./dataset_1000/imgs
# Đã copy: 97ca89c4d6f62bc1207a3bdf92c91612.jpg sang ./dataset_1000/imgs
# Đã copy: 5fce12895842606fbce9e4db24f12024.jpg sang ./dataset_1000/imgs
# Đã copy: de4264c7b1ed236b0dac83afef32c501.jpg sang ./dataset_1000/imgs
# Đã copy: 476b4fc48a736000dbbe4d7a8668e969.jpg sang ./dataset_1000/imgs
# Đã copy: 0ea8d51bc9a127d5c1b04f52da2a3831.jpg sang ./dataset_1000/imgs
# Đã copy: 9d17d6cfbebd76d1f5ac3bd341862efb.jpg sang ./dataset_1000/imgs
# Đã copy: a58c30fa9e74c7aba3ff778c264266dc.jpg sang ./dataset_1000/imgs
# Đã copy: b0d7795151bb4e43cc4cddd1e9026c28.jpg sang ./dataset_1000/imgs
# Đã copy: 982775757247ea8e07219f5c160da6b4.jpg sang ./dataset_1000/imgs
# Đã copy: 97c167ffd7863a50f7889ec43781a559.jpg sang ./dataset_1000/imgs
# Đã copy: bac2b7dc91176e0fb649a2ff231e1544.jpg sang ./dataset_1000/imgs
# Đã copy: 1c8cad66f4b3819de014d061ed942090.jpg sang ./dataset_1000/imgs
# Đã copy: 64e017572f6c6a688e2c1ad5b0db94a1.jpg sang ./dataset_1000/imgs
# Đã copy: fff132f7ce55db363a1afc4fda330ffc.jpg sang ./dataset_1000/imgs
# Đã copy: 0b263ec134fc202b6d285a1b999b396e.jpg sang ./dataset_1000/imgs
# Đã copy: 3ae1c999a49f8dcb2d2f3a48cfc17483.jpg sang ./dataset_1000/imgs
# Đã copy: c44c8baabdde89ee8d1c57e25e629d2c.jpg sang ./dataset_1000/imgs
# Đã copy: 53d0ee82b3b7200b3cec8c3c1becead9.jpg sang ./dataset_1000/imgs
# Đã copy: 48eae93948ceb80935dd2aa070236576.jpg sang ./dataset_1000/imgs
# Đã copy: 7bcea0722c0fd980bd6c9dbe6bc01024.jpg sang ./dataset_1000/imgs
# Đã copy: fd5474f7b0793200fbec993c1b441555.jpg sang ./dataset_1000/imgs
# Đã copy: b6d02bbe09572234c2123bebb2008827.jpg sang ./dataset_1000/imgs
# Đã copy: 50fe1321ccc1486f1c79568ef0f9d18b.jpg sang ./dataset_1000/imgs
# Đã copy: a847e30a77f9e4a2ee048eec5c5aaac7.jpg sang ./dataset_1000/imgs
# Đã copy: 1c9c4ae7b1fc607ba14fcd5d55c0490c.jpg sang ./dataset_1000/imgs
# Đã copy: 4a9b404eb560d13022b39a1b2cb13636.jpg sang ./dataset_1000/imgs
# Đã copy: 786039c30bda71f524e00f2b18a726d9.jpg sang ./dataset_1000/imgs
# Đã copy: 182d4ad5d1220aeec1a26417fadf66eb.jpg sang ./dataset_1000/imgs
# Đã copy: 5cbfafc69188a60f3b8c8c5bcadce0f8.jpg sang ./dataset_1000/imgs
# Đã copy: d900d8a0ed90b9842545c6636db73bd8.jpg sang ./dataset_1000/imgs
# Đã copy: 92b9103f723daaef2408268684aeacfb.jpg sang ./dataset_1000/imgs
# Đã copy: 0a5f42e306446625d6f000bf664f5051.jpg sang ./dataset_1000/imgs
# Đã copy: 49834f46009d11fd1dfd226104b74416.jpg sang ./dataset_1000/imgs
# Đã copy: afd155e10e202f360f3d88d9715b2b50.jpg sang ./dataset_1000/imgs
# Đã copy: a933a9c3f58d0b8da300a8cb6e7bcfd7.jpg sang ./dataset_1000/imgs
# Đã copy: 968776fa952b2363584aa2c6cc47dc18.jpg sang ./dataset_1000/imgs
# Đã copy: fb911313fa0e68a78fd956a458fecd0a.jpg sang ./dataset_1000/imgs
# Đã copy: 38f0107b94d67a2603872a07edeaf8e4.jpg sang ./dataset_1000/imgs
# Đã copy: 0a51803550d847749e11e9de2ef14c69.jpg sang ./dataset_1000/imgs
# Đã copy: fbc604a00ac5d9d6a73cec8789a75d0c.jpg sang ./dataset_1000/imgs
# Đã copy: 4c61f0cf8f68683bebae793d952ac54c.jpg sang ./dataset_1000/imgs
# Đã copy: 18cb6ad25627b7f5dd70fda4b18a3b8b.jpg sang ./dataset_1000/imgs
# Đã copy: 87706bb6ede4b987dd694f4cb0c2d47b.jpg sang ./dataset_1000/imgs
# Đã copy: 1af51266dbe3f33f6ca566085c520667.jpg sang ./dataset_1000/imgs
# Đã copy: 23c6d4c3f69c4883ef65e139b56abc91.jpg sang ./dataset_1000/imgs
# Đã copy: 2712311dd02d39b741b0305333efd34e.jpg sang ./dataset_1000/imgs
# Đã copy: ee01140f6794177d45eaae93f70636f4.jpg sang ./dataset_1000/imgs
# Đã copy: 58cbc774af717175017ec0f01d7f892a.jpg sang ./dataset_1000/imgs
# Đã copy: b5c847e295bb09c364f8ca4eba3ed5fa.jpg sang ./dataset_1000/imgs
# Đã copy: 7b029e9794a7d693cb2802e943b29254.jpg sang ./dataset_1000/imgs
# Đã copy: 389d65dec1bdfdd13d7cea08f6191eba.jpg sang ./dataset_1000/imgs
# Đã copy: d41ea7d90977d8b75119d92994f59e29.jpg sang ./dataset_1000/imgs
# Đã copy: 49986d7c548a65a68a918fd0267b1d31.jpg sang ./dataset_1000/imgs
# Đã copy: b35f2db2a616be47f6d339deeda24fb4.jpg sang ./dataset_1000/imgs
# Đã copy: 2cc7d97fbfb64cec81a3b83db2c2f351.jpg sang ./dataset_1000/imgs
# Đã copy: 99ba5476dafeec7133848e732a087bd5.jpg sang ./dataset_1000/imgs
# Đã copy: dcc1a0750ea376beb72f18929a7a1230.jpg sang ./dataset_1000/imgs
# Đã copy: 2eb9b4ffb96c1930465ac46c53e9dac8.jpg sang ./dataset_1000/imgs
# Đã copy: f516bcafe87e1b3736f43dc8323389eb.jpg sang ./dataset_1000/imgs
# Đã copy: 656fa92898432be2167d03c7968ea0a9.jpg sang ./dataset_1000/imgs
# Đã copy: 2aa840b98308479a14e8c40c0412d044.jpg sang ./dataset_1000/imgs
# Đã copy: a5215bf0a67b46153139e08cc91dba30.jpg sang ./dataset_1000/imgs
# Đã copy: 701335b4d8bae768f637a4c15ce9d606.jpg sang ./dataset_1000/imgs
# Đã copy: 9f44dafc21d52a97f6ecc6891483804a.jpg sang ./dataset_1000/imgs
# Đã copy: d9b4ae1fe216fbb06e6f371887d6909c.jpg sang ./dataset_1000/imgs
# Đã copy: dfb7955b1e7ce47ba4ffb2afdf337467.jpg sang ./dataset_1000/imgs
# Đã copy: 0a1570130bb7efdf2d9ff30cbe00d5e4.jpg sang ./dataset_1000/imgs
# Đã copy: 4146d7aaba9313457c7394ef38039514.jpg sang ./dataset_1000/imgs
# Đã copy: 3044e58d34822e047d6fbd5b9cc299c3.jpg sang ./dataset_1000/imgs
# Đã copy: 402b73318d1ffd2df9292279bfe2c822.jpg sang ./dataset_1000/imgs
# Đã copy: 96309d879c254cc45ce0ef8cabf77853.jpg sang ./dataset_1000/imgs
# Đã copy: b50fdb842cbdd1c0aa79fc82faeb0188.jpg sang ./dataset_1000/imgs
# Đã copy: 4fc8cbb77340a45fe7fb4a8ffda20e62.jpg sang ./dataset_1000/imgs
# Đã copy: 634e750f9655592aad05ae6840b9ed68.jpg sang ./dataset_1000/imgs
# Đã copy: a8883aef64f6e82b9d871bd94b94b033.jpg sang ./dataset_1000/imgs
# Đã copy: b2b861f27cb2ca3fc4455d3301dd4661.jpg sang ./dataset_1000/imgs
# Đã copy: 127e043ce0b8e0dc175e6af0d227a359.jpg sang ./dataset_1000/imgs
# Đã copy: 2eeb21666cfc86ef4ab45abd867c9ad4.jpg sang ./dataset_1000/imgs
# Đã copy: d26a7e3009c52ee31df4dc0fe4080453.jpg sang ./dataset_1000/imgs
# Đã copy: da688f1f46dc0e9d9b423854ffd36200.jpg sang ./dataset_1000/imgs
# Đã copy: c150f8e024712ed0f22326acdcb98a1b.jpg sang ./dataset_1000/imgs
# Đã copy: f3b8dc8e93e7cda96ecd4fd3c94f56e0.jpg sang ./dataset_1000/imgs
# Đã copy: 7d296180af9d99f4b0136ee4c03608d6.jpg sang ./dataset_1000/imgs
# Đã copy: d0b86514251a73670ce42ac2605cb54e.jpg sang ./dataset_1000/imgs
# Đã copy: 30374292c6d9f05d3058c64f23532130.jpg sang ./dataset_1000/imgs
# Đã copy: bfbdba610529c3409c87c066994ac163.jpg sang ./dataset_1000/imgs
# Đã copy: 3c2a4a97a6326a67b36466a646f39d39.jpg sang ./dataset_1000/imgs
# Đã copy: 41b46bfe9f57b27c58b6e6507c8bed7f.jpg sang ./dataset_1000/imgs
# Đã copy: bdcebf2f58ef8071d14817e2a3b0eedf.jpg sang ./dataset_1000/imgs
# Đã copy: ccb67f0a5eb657ed25b6e5bb78e30d6f.jpg sang ./dataset_1000/imgs
# Đã copy: 88306998a04fa616640ddd75358d1ea6.jpg sang ./dataset_1000/imgs
# Đã copy: 0e2874c0aaa02bde21d03ea0f7de2aa8.jpg sang ./dataset_1000/imgs
# Đã copy: 6c1242263bc253e12da4fd30267633cc.jpg sang ./dataset_1000/imgs
# Đã copy: f4856eaab1985892e8f6ae72cfe12b20.jpg sang ./dataset_1000/imgs
# Đã copy: 2fccd79c2fd64675031ee72ee4cf888a.jpg sang ./dataset_1000/imgs
# Đã copy: ab7386177d7949f81cf4c5acf40ee02a.jpg sang ./dataset_1000/imgs
# Đã copy: 0702b00b8976647d94b854ae5ee8e5d8.jpg sang ./dataset_1000/imgs
# Đã copy: 3120babbc0c36d9dfe800ecac3d9ecd1.jpg sang ./dataset_1000/imgs
# Đã copy: de9aceb2fe19a48ca4b37ce0b506001c.jpg sang ./dataset_1000/imgs
# Đã copy: 3456a353e9de82e1f9e9cf1b20188146.jpg sang ./dataset_1000/imgs
# Đã copy: df3ae6b86e0fa2e06578e2056acc0448.jpg sang ./dataset_1000/imgs
# Đã copy: 560ceedfed1d2a9e1f519942a7965197.jpg sang ./dataset_1000/imgs
# Đã copy: 036f89ed4fb4c9a4a2bee1515dc2cc5e.jpg sang ./dataset_1000/imgs
# Đã copy: f770cfa1c6dd5a1aec50993f198f90c0.jpg sang ./dataset_1000/imgs
# Đã copy: fffe20b555b98c3c1f26c8dfff275cbc.jpg sang ./dataset_1000/imgs
# Đã copy: 31cdf9c998336df540c3f36acf4507c7.jpg sang ./dataset_1000/imgs
# Đã copy: 5c816abf8e2ff6afa92ac421cb12b55d.jpg sang ./dataset_1000/imgs
# Đã copy: 62e50b27812fcc87bf10f48951481632.jpg sang ./dataset_1000/imgs
# Đã copy: 973514e948acbb44882d3bb221c15bab.jpg sang ./dataset_1000/imgs
# Đã copy: 66f20c610d93433c4e531d039cdcdf68.jpg sang ./dataset_1000/imgs
# Đã copy: 266e137ed789e0f9056907fa6d698286.jpg sang ./dataset_1000/imgs
# Đã copy: 7758f93e5e30e38b900d55d1a3f9e45e.jpg sang ./dataset_1000/imgs
# Đã copy: 187a5fa826aac6f9ea71cab6ca29e521.jpg sang ./dataset_1000/imgs
# Đã copy: 66a4ed3a2a44a4050323efa551060f55.jpg sang ./dataset_1000/imgs
# Đã copy: 999bd61d2fe9ad0e89dddb33a12b2dc2.jpg sang ./dataset_1000/imgs
# Đã copy: d220e597a5df7e201172bfd097e58fe3.jpg sang ./dataset_1000/imgs
# Đã copy: d552bce26b4982575b4ce423bb3c3636.jpg sang ./dataset_1000/imgs
# Đã copy: 5ea8a93de0318e5005cc211c375f853c.jpg sang ./dataset_1000/imgs
# Đã copy: a6a9733c83907376f8d656b4f910ec2b.jpg sang ./dataset_1000/imgs
# Đã copy: 1ed9ecaa49fcf435acd802b75ba4a026.jpg sang ./dataset_1000/imgs
# Đã copy: c67fc7b56855ab1297cbcb8cbf54cd18.jpg sang ./dataset_1000/imgs
# Đã copy: e5aacc310b5e9274a2fd9552f136fdec.jpg sang ./dataset_1000/imgs
# Đã copy: e5273165ad2eec901cd50f90505e2e87.jpg sang ./dataset_1000/imgs
# Đã copy: 2648285eb58187d388d2ec13e46495ed.jpg sang ./dataset_1000/imgs
# Đã copy: 4103ae509d6d30c5c866f98c602236d4.jpg sang ./dataset_1000/imgs
# Đã copy: 3836a553d8df35f2f3e9d79fe382bdc5.jpg sang ./dataset_1000/imgs
# Đã copy: 4aa711ddb2ae40d5f5b89fcded249764.jpg sang ./dataset_1000/imgs
# Đã copy: 5fb823fa7f3d1fabd5b3fa868761b2ac.jpg sang ./dataset_1000/imgs
# Đã copy: 9bc0a658bf8d5c7190b889984c672618.jpg sang ./dataset_1000/imgs
# Đã copy: 6c6c791a25a7d8727aaaff7db74bfe32.jpg sang ./dataset_1000/imgs
# Đã copy: 1e0a40b1e63a923b775bb19976a100ca.jpg sang ./dataset_1000/imgs
# Đã copy: c999f3d3f24fa4b52793749b9d0cddbf.jpg sang ./dataset_1000/imgs
# Đã copy: 4fd633d09ad0ebd2849d832bf61fe753.jpg sang ./dataset_1000/imgs
# Đã copy: 7522ef707e35e18efba7ae5363f18c0d.jpg sang ./dataset_1000/imgs
# Đã copy: cee5ef4ec88b2ed924c9a78ba3ab9ef3.jpg sang ./dataset_1000/imgs
# Đã copy: 7c10c4e7727531ed44d5530c59467f91.jpg sang ./dataset_1000/imgs
# Đã copy: d0d9d7d3d689f1bf340dd27ccaad8011.jpg sang ./dataset_1000/imgs
# Đã copy: 07a08aff48e8335c8188ee681e3e35bd.jpg sang ./dataset_1000/imgs
# Đã copy: 972ea7058027245ec527bf997eaa8fd7.jpg sang ./dataset_1000/imgs
# Đã copy: 91a765e3b8a8d1fbc94265828372bdb6.jpg sang ./dataset_1000/imgs
# Đã copy: f81dba0892a7d61fa0bd2e85ae4dc87c.jpg sang ./dataset_1000/imgs
# Đã copy: 7208bc873fb0e5b2757c0827610dd32a.jpg sang ./dataset_1000/imgs
# Đã copy: cda8e216a526a0fd3b0c0331fc8d25fc.jpg sang ./dataset_1000/imgs
# Đã copy: 1ab6db4bb643878c339606f14a4e0ae9.jpg sang ./dataset_1000/imgs
# Đã copy: f08abc73a82adca2bbb2304c62991458.jpg sang ./dataset_1000/imgs
# Đã copy: f195e741b7a391d26d0d97483ce9ce13.jpg sang ./dataset_1000/imgs
# Đã copy: 5567c8edbcb209fff2685893a5eb295f.jpg sang ./dataset_1000/imgs
# Đã copy: 3dd23bd8fe812d13372fa99c068bffe5.jpg sang ./dataset_1000/imgs
# Đã copy: bbe44cda55554087763ca9cce2bb74df.jpg sang ./dataset_1000/imgs
# Đã copy: ad60b28330428ad6643154a22813f81d.jpg sang ./dataset_1000/imgs
# Đã copy: b8b2bfb169edb95feda7dd029571a2de.jpg sang ./dataset_1000/imgs
# Đã copy: 078eb35de9fd82369e286d986e54ab8f.jpg sang ./dataset_1000/imgs
# Đã copy: 0c5ae4599080d1f1705e70a7e8aafb7b.jpg sang ./dataset_1000/imgs
# Đã copy: dcbbbd5edb2fa41a515522662e880ca5.jpg sang ./dataset_1000/imgs
# Đã copy: 3ea8c14294e265a9bc3e89855137268a.jpg sang ./dataset_1000/imgs
# Đã copy: e20de662619aa17bfca1380412a44fa4.jpg sang ./dataset_1000/imgs
# Đã copy: a9f4a3ee2ff5cac582a5cf26c7aa755e.jpg sang ./dataset_1000/imgs
# Đã copy: 7072690c956e76ee685fb642f8eed98b.jpg sang ./dataset_1000/imgs
# Đã copy: 19ccc5554744169dd6eebb97678dadf3.jpg sang ./dataset_1000/imgs
# Đã copy: eb60c48a5c308462d6809ab289ce2396.jpg sang ./dataset_1000/imgs
# Đã copy: 3e4e4bef04837dde43064c20010d5f1b.jpg sang ./dataset_1000/imgs
# Đã copy: 0040e5863c5e6197cd264509bc2fbb1c.jpg sang ./dataset_1000/imgs
# Đã copy: 60645ee11d219105097b13b6e70606fe.jpg sang ./dataset_1000/imgs
# Đã copy: c51dde86f437d7ce849d490791bc973d.jpg sang ./dataset_1000/imgs
# Đã copy: 4354ac9aabea34991b82b506c425e774.jpg sang ./dataset_1000/imgs
# Đã copy: f20de5b6356da5f1e38626064c8ac85e.jpg sang ./dataset_1000/imgs
# Đã copy: 06fb66c3c082f6214edb3942fb5f0133.jpg sang ./dataset_1000/imgs
# Đã copy: 146a1d4e731158599485e108016aef2a.jpg sang ./dataset_1000/imgs
# Đã copy: 0e31655f3e07cf018edc4c16511c16c8.jpg sang ./dataset_1000/imgs
# Đã copy: 711e78900add00d4382192eb86e8d38e.jpg sang ./dataset_1000/imgs
# Đã copy: 67eb420f5c9fb986a6a04706a8d1e10b.jpg sang ./dataset_1000/imgs
# Đã copy: 6616c4cb7f0fe7d07e137a458dfba379.jpg sang ./dataset_1000/imgs
# Đã copy: efaed56da674aff2d57ef8a11eea693b.jpg sang ./dataset_1000/imgs
# Đã copy: 6d7fab9d9742619e3c9f55422f8ca772.jpg sang ./dataset_1000/imgs
# Đã copy: fb43e2f398dc39441f139b76e44be7bf.jpg sang ./dataset_1000/imgs
# Đã copy: 18c22e4febd60c299968537bb35bbd2a.jpg sang ./dataset_1000/imgs
# Đã copy: 385b1c02089ac6040183e4ac697aae59.jpg sang ./dataset_1000/imgs
# Đã copy: e0d6c42421f6a21aa2d7efd1096f8ce1.jpg sang ./dataset_1000/imgs
# Đã copy: c545dd47de77ec9acda8b104e3b0168a.jpg sang ./dataset_1000/imgs
# Đã copy: 3717c29a3b28aafcfd43dfe3b158e0e8.jpg sang ./dataset_1000/imgs
# Đã copy: 3e73c1da2d36dd282e80d9ae2a57a072.jpg sang ./dataset_1000/imgs
# Đã copy: cce661a0e8e7ffd41faad3231f54f82d.jpg sang ./dataset_1000/imgs
# Đã copy: 240998abbac878ce554738321c57c5fa.jpg sang ./dataset_1000/imgs
# Đã copy: 336fa2bfbd86bfb93d520e7399501aab.jpg sang ./dataset_1000/imgs
# Đã copy: 338f467605da31624891c26ca8857e81.jpg sang ./dataset_1000/imgs
# Đã copy: f4996e8f3f3711573a7ae10b62f06a74.jpg sang ./dataset_1000/imgs
# Đã copy: f3516d0f889069ded9d7988f2d4e6d16.jpg sang ./dataset_1000/imgs
# Đã copy: 810c77a2dc87485ad8b01148d7934e16.jpg sang ./dataset_1000/imgs
# Đã copy: c770483f62f3b820b38b3153244feb4d.jpg sang ./dataset_1000/imgs
# Đã copy: 5633efae2ffbe7e648b51e3612d84978.jpg sang ./dataset_1000/imgs
# Đã copy: 26f01130dd2b4851fd82080b68a6dde4.jpg sang ./dataset_1000/imgs
# Đã copy: 0a022a2ee3e927ece09385eff2f2fb76.jpg sang ./dataset_1000/imgs
# Đã copy: 196a73e8ba3ac30191559342ca897c0b.jpg sang ./dataset_1000/imgs
# Đã copy: 3d7bb4b89171b4586ae2bc5b8970ffa4.jpg sang ./dataset_1000/imgs
# Đã copy: 6ca6d11886cf63883e44cfaba8bfebdd.jpg sang ./dataset_1000/imgs
# Đã copy: e74fb435305fbc8454a976304ff3bfbf.jpg sang ./dataset_1000/imgs
# Đã copy: a91f0cc3235769137c55f5d64bfee198.jpg sang ./dataset_1000/imgs
# Đã copy: 452a18d00292e4ba5e12cb600814768b.jpg sang ./dataset_1000/imgs
# Đã copy: f7d81f69d8720903e138e439b6ee9d47.jpg sang ./dataset_1000/imgs
# Đã copy: 619511854818d344232335afd4c4cf2c.jpg sang ./dataset_1000/imgs
# Đã copy: 30eb50766625c7c4bcc241e21f370f91.jpg sang ./dataset_1000/imgs
# Đã copy: c36b9047fa5f50bdc4266e81d83622db.jpg sang ./dataset_1000/imgs
# Đã copy: 03572beab54d343a740cf04a92148ff5.jpg sang ./dataset_1000/imgs
# Đã copy: 48ba3723744b953bacd3a2b33280f812.jpg sang ./dataset_1000/imgs
# Đã copy: ca2cbe58ff293e17af0d5ee363652702.jpg sang ./dataset_1000/imgs
# Đã copy: d0bdff60fa376e3010e623cc1e8eb698.jpg sang ./dataset_1000/imgs
# Đã copy: 2b8255ddd13a904d2ecb6359027c7b04.jpg sang ./dataset_1000/imgs
# Đã copy: 6cd1aa58c7575a450d05878a752ba2ca.jpg sang ./dataset_1000/imgs
# Đã copy: 2f42a9658574e2f3535879a506078500.jpg sang ./dataset_1000/imgs
# Đã copy: fafc70c30254ead5aa96f1d3bedb3b55.jpg sang ./dataset_1000/imgs
# Đã copy: 37e79ce6b56b3f6451c9c35ca9cac1a4.jpg sang ./dataset_1000/imgs
# Đã copy: e97053286b54781ba9ff6a51e8861017.jpg sang ./dataset_1000/imgs
# Đã copy: d820f64f1f3846a7511b34439c5d1dfd.jpg sang ./dataset_1000/imgs
# Đã copy: f6e54f347f7990460a065941857ba276.jpg sang ./dataset_1000/imgs
# Đã copy: 497ddde217406f66ee6773637912481b.jpg sang ./dataset_1000/imgs
# Đã copy: 2410752e5abb3197416acea4d58ed5b7.jpg sang ./dataset_1000/imgs
# Đã copy: aeb7df8c570c399fb75ee7d518028489.jpg sang ./dataset_1000/imgs
# Đã copy: 378afce2c8538ee5ce18e36add218720.jpg sang ./dataset_1000/imgs
# Đã copy: 092a1f6fc4336c563a624eaa6acd30f7.jpg sang ./dataset_1000/imgs
# Đã copy: ee69cd0e762c9cc17bafbff7c3a1d7bd.jpg sang ./dataset_1000/imgs
# Đã copy: a22e0e449809d1c852957b662b30d103.jpg sang ./dataset_1000/imgs
# Đã copy: 7678f7de4d5e8d732374d0362e8aebf2.jpg sang ./dataset_1000/imgs
# Đã copy: 8556e1ef660801d79527390db1a47547.jpg sang ./dataset_1000/imgs
# Đã copy: 24e08720f1619e87663a79d8ea5727a8.jpg sang ./dataset_1000/imgs
# Đã copy: f8851a7b34471f46e70fd13b93c24110.jpg sang ./dataset_1000/imgs
# Đã copy: d342d4cd053f0787d635f7ea2266a16a.jpg sang ./dataset_1000/imgs
# Đã copy: 6ea29b7ac8cd76fe6f24989e56d0cd8d.jpg sang ./dataset_1000/imgs
# Đã copy: d855775be6f967225dd279032c7d6728.jpg sang ./dataset_1000/imgs
# Đã copy: 3772b3959acfe39cc91d12a72780c018.jpg sang ./dataset_1000/imgs
# Đã copy: b0dfa3af76b0f536961cac541e3e89b1.jpg sang ./dataset_1000/imgs
# Đã copy: ec43bc5017fa93c00f193a8e6d925f5d.jpg sang ./dataset_1000/imgs
# Đã copy: 8307a8ad6fd040d0bb3194db9a23dc64.jpg sang ./dataset_1000/imgs
# Đã copy: 44d00e91584e9bb36e376c0e2a1020c9.jpg sang ./dataset_1000/imgs
# Đã copy: 2299df83452c1e16eae4392690981c4c.jpg sang ./dataset_1000/imgs
# Đã copy: 551a824ab6f02ff2eb14461a9968938e.jpg sang ./dataset_1000/imgs
# Đã copy: 8734a7841a0b5e13580e20007a16ae30.jpg sang ./dataset_1000/imgs
# Đã copy: f4ee1b8602b31ea1ef5ab3197a93586d.jpg sang ./dataset_1000/imgs
# Đã copy: cfb0cabc1f4a7263f106f7014cf5ea6f.jpg sang ./dataset_1000/imgs
# Đã copy: a66031d2b2827029cd560d29a76ee157.jpg sang ./dataset_1000/imgs
# Đã copy: b0bd07701c06abb302029f30ebc07acc.jpg sang ./dataset_1000/imgs
# Đã copy: 5cc4e6c0191fb96a9e1c7f388ceeb06f.jpg sang ./dataset_1000/imgs
# Đã copy: 791573c3e7f9688468d83cca7e7426f3.jpg sang ./dataset_1000/imgs
# Đã copy: f523abcd128930865d2c607c836b7874.jpg sang ./dataset_1000/imgs
# Đã copy: a36b6b488de15e7e03fde61b376d75ab.jpg sang ./dataset_1000/imgs
# Đã copy: a4e7c1de00d92a1c4ccc15398fcd0a89.jpg sang ./dataset_1000/imgs
# Đã copy: 217c5b99879430c1cfcb2b3c54eafa5a.jpg sang ./dataset_1000/imgs
# Đã copy: b685b91ecd51a69ba083aa4241635752.jpg sang ./dataset_1000/imgs
# Đã copy: f345a31b3b1a67b6e2f9431c0df43a76.jpg sang ./dataset_1000/imgs
# Đã copy: b3aa187f4581875d366b28676267df9e.jpg sang ./dataset_1000/imgs
# Đã copy: dccb13a88ab94839c115c8791ce9987f.jpg sang ./dataset_1000/imgs
# Đã copy: 1320ec395c35ce61aec30b81e3604184.jpg sang ./dataset_1000/imgs
# Đã copy: c61e368cddd904468b56149c212f43e3.jpg sang ./dataset_1000/imgs
# Đã copy: a44b5aedff3cf989488def5aa6e7d413.jpg sang ./dataset_1000/imgs
# Đã copy: d7ed49bf3c669cf52d12a38ca8b5b05a.jpg sang ./dataset_1000/imgs
# Đã copy: 0ce926b55e237f5351b4d5d1a09bac3a.jpg sang ./dataset_1000/imgs
# Đã copy: 245d847002a9be453b4a282c7452be63.jpg sang ./dataset_1000/imgs
# Đã copy: e91d5d1ca2cc89e33daaf0c47a901183.jpg sang ./dataset_1000/imgs
# Đã copy: 93d525fc9f934c60ed2dc7c5e75c10c5.jpg sang ./dataset_1000/imgs
# Đã copy: 66eaea62b60752d229c6b016d330a986.jpg sang ./dataset_1000/imgs
# Đã copy: 22eeedea413f782236f8fc01897501a2.jpg sang ./dataset_1000/imgs
# Đã copy: dbeb8e9f68f3cc4627f487718714c1bb.jpg sang ./dataset_1000/imgs
# Đã copy: c0c3c726bdc70bcb5cd84128dc71b108.jpg sang ./dataset_1000/imgs
# Đã copy: 011720c002b9342864ed909378babba8.jpg sang ./dataset_1000/imgs
# Đã copy: 61e3cefe931a61ac97e4fc1889b4303d.jpg sang ./dataset_1000/imgs
# Đã copy: 76e60dfaddf1600bb09029701c274539.jpg sang ./dataset_1000/imgs
# Đã copy: 969c3b42bcace4a5db03b732582b6b65.jpg sang ./dataset_1000/imgs
# Đã copy: 1731c612d8d2096a92bcfcc5b0a04984.jpg sang ./dataset_1000/imgs
# Đã copy: 97dc6ddb952c0ba81111ca25b9ed5b0f.jpg sang ./dataset_1000/imgs
# Đã copy: f17d7f44944dd449a2e0b5af5bfe4e44.jpg sang ./dataset_1000/imgs
# Đã copy: 8fd72eac38225a2c1a7e4bcbaea79675.jpg sang ./dataset_1000/imgs
# Đã copy: e6c9e1d6472864ac275565225d58dc01.jpg sang ./dataset_1000/imgs
# Đã copy: cc7b3a7cc7fafdd3a9738142337bcc3e.jpg sang ./dataset_1000/imgs
# Đã copy: 98ea724d81ce61ca7f265d1658a51e0d.jpg sang ./dataset_1000/imgs
# Đã copy: b667888ff0e525f3b9dea22b5eacc895.jpg sang ./dataset_1000/imgs
# Đã copy: afb0bf29b91518989cb207c98a7850b7.jpg sang ./dataset_1000/imgs
# Đã copy: 548bf88dad60a1e9b34cce319feb72b1.jpg sang ./dataset_1000/imgs
# Đã copy: 82bd8c4f98a38988d194c97e39c74b1b.jpg sang ./dataset_1000/imgs
# Đã copy: 5ea805524a4d9acf7d9d91fc2c916386.jpg sang ./dataset_1000/imgs
# Đã copy: bec73e867302eac2a84020ca4020e447.jpg sang ./dataset_1000/imgs
# Đã copy: 51fe31fb1c754136a7fd510919889a49.jpg sang ./dataset_1000/imgs
# Đã copy: cfcc49f06f0b98660f2b1d800bc10117.jpg sang ./dataset_1000/imgs
# Đã copy: e8f610a3f563a039d3ae947391894b37.jpg sang ./dataset_1000/imgs
# Đã copy: d0c9cd6e87ae6b5f86d3f0120f3a5f25.jpg sang ./dataset_1000/imgs
# Đã copy: 60f6cee70ad6ef27ac5458e312fa2222.jpg sang ./dataset_1000/imgs
# Đã copy: c6001a519699a33e6d717ac23eab5ff5.jpg sang ./dataset_1000/imgs
# Đã copy: d7d905c6be33e52360ada7cdd6d1aae0.jpg sang ./dataset_1000/imgs
# Đã copy: 921c8c66880a6df156acc38ace3845ef.jpg sang ./dataset_1000/imgs
# Đã copy: e76dcc20296f753235bd1929d70e57c6.jpg sang ./dataset_1000/imgs
# Đã copy: 1144e70dcf1eaf63ee3f845026eac8de.jpg sang ./dataset_1000/imgs
# Đã copy: 7aff4f7eed6c19e18b5d16c1cc4dbb78.jpg sang ./dataset_1000/imgs
# Đã copy: 81d6291cbddb144e40975378c36d8a9e.jpg sang ./dataset_1000/imgs
# Đã copy: 356ff49b21a4348357ae260174047981.jpg sang ./dataset_1000/imgs
# Đã copy: 81602aa30291923338e2db10f5f87475.jpg sang ./dataset_1000/imgs
# Đã copy: 9020535c1aa140348fbbd2b2146803b8.jpg sang ./dataset_1000/imgs
# Đã copy: 1d4070b8a07b418e2cd8aeb947989ea6.jpg sang ./dataset_1000/imgs
# Đã copy: 67ad224b263f331650e6d9d45a3ddcb5.jpg sang ./dataset_1000/imgs
# Đã copy: 71e9b0adb502858db1770a0307f300a5.jpg sang ./dataset_1000/imgs
# Đã copy: 15d4a8c4bdda2ddc716c1b7dbd88c4ca.jpg sang ./dataset_1000/imgs
# Đã copy: dbfe4218392eec44e7305c06bddb9c0d.jpg sang ./dataset_1000/imgs
# Đã copy: bf916d052b55032ed19b91343ae64055.jpg sang ./dataset_1000/imgs
# Đã copy: 78e6643328a8294d06bf5180d1893859.jpg sang ./dataset_1000/imgs
# Đã copy: 5fcd2f561035be0aaeca593b31477003.jpg sang ./dataset_1000/imgs
# Đã copy: b53bbdb6698bf1c2c45b95150df91f8b.jpg sang ./dataset_1000/imgs
# Đã copy: 62904c54daca780e81d5531f077d454a.jpg sang ./dataset_1000/imgs
# Đã copy: 97daa7f8ae52ba7f537955c9c2c27322.jpg sang ./dataset_1000/imgs
# Đã copy: 829c3829fa4a52e6c5330902fcdf0609.jpg sang ./dataset_1000/imgs
# Đã copy: 2c86bcfe601b4803c69d3eecb1011c2a.jpg sang ./dataset_1000/imgs
# Đã copy: 9e61926bddbdb10b702f0522e19a4188.jpg sang ./dataset_1000/imgs
# Đã copy: 37ca103bd9d6c3f30e1d84fa74761c96.jpg sang ./dataset_1000/imgs
# Đã copy: 4955eda5cdd203e41b018dc88b5af0f9.jpg sang ./dataset_1000/imgs
# Đã copy: 783e29c3b47d0130e8ea5ad063e58233.jpg sang ./dataset_1000/imgs
# Đã copy: d53e71f15cb3080e06a563d386a22a93.jpg sang ./dataset_1000/imgs
# Đã copy: 81ee52c0aa01624e7bb13459f516d617.jpg sang ./dataset_1000/imgs
# Đã copy: a51386c99d81279142d86bfda7ac68df.jpg sang ./dataset_1000/imgs
# Đã copy: 0daaf1a03c6a6a3caaadf95f0f799b4c.jpg sang ./dataset_1000/imgs
# Đã copy: 4fb74d9b3ced1779464e1308d856fccb.jpg sang ./dataset_1000/imgs
# Đã copy: 40c0a4402f76b01c1fce0dfa9359be5f.jpg sang ./dataset_1000/imgs
# Đã copy: d961256e1dbe407c82570fe518257b20.jpg sang ./dataset_1000/imgs
# Đã copy: 122f879efbb349c3587371f16497c752.jpg sang ./dataset_1000/imgs
# Đã copy: 3463f1110493bbd53036447decfb1634.jpg sang ./dataset_1000/imgs
# Đã copy: 106ec72949d5e5dc0344ed57540af06c.jpg sang ./dataset_1000/imgs
# Đã copy: 0338530ca518db2d680f76f5cbe7f0c8.jpg sang ./dataset_1000/imgs
# Đã copy: 878401dccb59883e4c84dcc6a4663395.jpg sang ./dataset_1000/imgs
# Đã copy: 2aa160207df1892bfce8b7d5e20c2814.jpg sang ./dataset_1000/imgs
# Đã copy: 473b48cfb6814558940a688063aaf402.jpg sang ./dataset_1000/imgs
# Đã copy: 69273fdd7f970a47b7e33a71f14ce7d5.jpg sang ./dataset_1000/imgs
# ...
# Đã copy: 2cff44712fabc05a9a32eec851f98c9e.jpg sang ./dataset_1000/imgs
# Đã copy: c0aae00313292e8c3d980ffd9979d7e6.jpg sang ./dataset_1000/imgs
# Đã copy: c74e112a4ac66f54b1925c48ce29178b.jpg sang ./dataset_1000/imgs
# Đã copy: 7178d8d4663dcb0a0888de41949ba84c.jpg sang ./dataset_1000/imgs
# Đã copy: aec9a53cb61abeaf9d777f27a3f74a4f.jpg sang ./dataset_1000/imgs
# Đã copy: 807a3b4212965dc75622056783fe7c85.jpg sang ./dataset_1000/imgs
# Đã copy: e9a84014850294595c3027a54dff495a.jpg sang ./dataset_1000/imgs
# Đã copy: ac22524cee2069a528881efcb8cfe8bc.jpg sang ./dataset_1000/imgs
# Đã copy: 357f9e8e9b38b3527f3be84dbc6e7b8a.jpg sang ./dataset_1000/imgs
# Đã copy: 4dea4e62bf2999531d5715bc0a904395.jpg sang ./dataset_1000/imgs
# Đã copy: ff5ff519f7b742f44e497a80ad1fc03a.jpg sang ./dataset_1000/imgs
# Đã copy: b406b506d316eec8f216db71d6b7c677.jpg sang ./dataset_1000/imgs
# Đã copy: 69ac3d6bd79342fcfa7cccce0d3e42f1.jpg sang ./dataset_1000/imgs
# Đã copy: ea362336e8ab82d802329a82b5f55cd8.jpg sang ./dataset_1000/imgs
# Đã copy: 8ef60cbedb83f5aaf96493d35746e917.jpg sang ./dataset_1000/imgs
# Đã copy: ef2fccc53f9493caf014d5fed597b935.jpg sang ./dataset_1000/imgs
# Đã copy: c911d5df12a5ac3d0af6a17cddb082d4.jpg sang ./dataset_1000/imgs
# Đã copy: 1c72087055b6b4094e619e2c7cec2ae7.jpg sang ./dataset_1000/imgs
# Đã copy: 8718e912183535f5e618697cdb96e646.jpg sang ./dataset_1000/imgs
# Đã copy: 18eb008a4f10863247469fee8decb8f6.jpg sang ./dataset_1000/imgs
# Đã copy: 90071c95e2fe54130a8b3f987b7e2e2c.jpg sang ./dataset_1000/imgs
# Đã copy: 9bbd3789e3eaefd5211a217d00e0da70.jpg sang ./dataset_1000/imgs
# Đã copy: 0f9ff356621a7461f54da12fa617590c.jpg sang ./dataset_1000/imgs
# Đã copy: 075d5650f908f2028200700bc6699f29.jpg sang ./dataset_1000/imgs
# Đã copy: 38b24922fb6a49f9e9b374fe5488c885.jpg sang ./dataset_1000/imgs
# Đã copy: 6b4ad1f8b51d39b6127c91e93a705394.jpg sang ./dataset_1000/imgs
# Đã copy: 9682d8aea4522ee0d4a6165b5147af65.jpg sang ./dataset_1000/imgs
# Đã copy: 7867ad9a4df1ed38ab8fd6308934734f.jpg sang ./dataset_1000/imgs
# Đã copy: 9b97a6c3d1dec01d09b4b63b5587c60d.jpg sang ./dataset_1000/imgs
# Đã copy: 20851e34802f2b58e3f807b9cb722714.jpg sang ./dataset_1000/imgs
# Đã copy: 0dfb466b1804028519fb4d268a22565b.jpg sang ./dataset_1000/imgs
# Đã copy: 7adbb19fa5d78e8750d693848c7241af.jpg sang ./dataset_1000/imgs
# Đã copy: 4ee55560326acdf214c702d1e338bf8b.jpg sang ./dataset_1000/imgs
# Đã copy: 13bfc3d0636bf9f7d4084d62caa44cce.jpg sang ./dataset_1000/imgs
# Đã copy: 68267b1c41a42679117473f7decb5233.jpg sang ./dataset_1000/imgs
# Đã copy: 7c65e5def84260428e87deb0f8152d83.jpg sang ./dataset_1000/imgs
# Đã copy: 1aa6d423d4e8257eb4ce1502620485bc.jpg sang ./dataset_1000/imgs
# Đã copy: 95fa4766556866e0a735ffda8301df4f.jpg sang ./dataset_1000/imgs
# Đã copy: ea4b1f27828cbd87b0f95f1f36cd7a54.jpg sang ./dataset_1000/imgs
# Đã copy: c94735bba05865b437c44010deaa22d1.jpg sang ./dataset_1000/imgs
# Đã copy: b791e0e78042f967216f671a63c2753f.jpg sang ./dataset_1000/imgs
# Đã copy: 70a0cba9ce97b436912819390fbc5b4d.jpg sang ./dataset_1000/imgs
# Đã copy: ec9eba05328040e50e8174abfa5c5056.jpg sang ./dataset_1000/imgs
# Đã copy: dd0abb819696f15d9e717b4e331f70cc.jpg sang ./dataset_1000/imgs
# Đã copy: f23e7f812b84654c00728b0acae71a88.jpg sang ./dataset_1000/imgs
# Đã copy: ac2e46a375fa1e6f5f7b0e31fc18444a.jpg sang ./dataset_1000/imgs
# Đã copy: 7d10f55b39803776354a115a9ee9d1c3.jpg sang ./dataset_1000/imgs
# Đã copy: d13e7444dc4b294ddafe39beb5025efb.jpg sang ./dataset_1000/imgs
# Đã copy: 2a7405ef74f2aa2e91daa615ae358f27.jpg sang ./dataset_1000/imgs
# Đã copy: 98b75136f439a0e5df1193ed86cec6c6.jpg sang ./dataset_1000/imgs
# Đã copy: 3d6e6ae49c1d88ed7b57d206acae66b6.jpg sang ./dataset_1000/imgs
# Đã copy: 6ee6f2d47970aecee2524066acf3a35f.jpg sang ./dataset_1000/imgs
# Đã copy: 571cacc53dfb44facf0bd55d3569098f.jpg sang ./dataset_1000/imgs
# Đã copy: 215631b4a0609666c8f537acc685bb9b.jpg sang ./dataset_1000/imgs
# Đã copy: 34cc770c3e0102175cedbd39fef44f7b.jpg sang ./dataset_1000/imgs
# Đã copy: d11326a9324da3f1167e590e7f55b3de.jpg sang ./dataset_1000/imgs
# Đã copy: e5def25bb3ef74d338bfe3738869cc9f.jpg sang ./dataset_1000/imgs
# Đã copy: 680c1356984a8c18f93fb5503f6175c9.jpg sang ./dataset_1000/imgs
# Đã copy: bc87a07c8e819e4f40d55ce1eda9e48e.jpg sang ./dataset_1000/imgs
# Đã copy: 065611cfd8ca1dbfeef4d58c975e3f39.jpg sang ./dataset_1000/imgs
# Đã copy: f195def869430ebea7a516f5c74ccb04.jpg sang ./dataset_1000/imgs
# Đã copy: 41b660a9746aaf3bd8aa2e9bbff11821.jpg sang ./dataset_1000/imgs
# Đã copy: 2b7c286fcacdc6e32340273df4c5569b.jpg sang ./dataset_1000/imgs
# Đã copy: accba3ce54c29723389ec7b197e6aebb.jpg sang ./dataset_1000/imgs
# Đã copy: f3fc465c726acba7e2feb1143f18798c.jpg sang ./dataset_1000/imgs
# Đã copy: 842f76683e799b685a5bf0b25b88a209.jpg sang ./dataset_1000/imgs
# Đã copy: b68ddc7f37b231502787fc8b1c02464c.jpg sang ./dataset_1000/imgs
# Đã copy: 89f53a2875464eae3a5ff8535c25ad6e.jpg sang ./dataset_1000/imgs
# Đã copy: 595c6a08f120a9de287fbc19aba5150b.jpg sang ./dataset_1000/imgs
# Đã copy: 0591284f15a0b5daeb767a7da62ea38f.jpg sang ./dataset_1000/imgs
# Đã copy: fafacbb169a778b799160b22ca8cfb3e.jpg sang ./dataset_1000/imgs
# Đã copy: ae81b1f20460316940df3965db53f030.jpg sang ./dataset_1000/imgs
# Đã copy: 5e3937204a82e85610d3f33574a924f8.jpg sang ./dataset_1000/imgs
# Đã copy: f2a3d647b207d016056408682183779c.jpg sang ./dataset_1000/imgs
# Đã copy: 9310ec2036269aa251496c9c7c8079f5.jpg sang ./dataset_1000/imgs
# Đã copy: 23becc64c2c9e43016d4d896b78fe962.jpg sang ./dataset_1000/imgs
# Đã copy: 72e53209d4d983117222210e18f5127d.jpg sang ./dataset_1000/imgs
# Đã copy: ae20760229bf2c3d3f7ea9e8d3c8447b.jpg sang ./dataset_1000/imgs
# Đã copy: c3b2b9ebbdd188698b3fb83ee68702a9.jpg sang ./dataset_1000/imgs
# Đã copy: c65e466b49fa542133021a786f069dc2.jpg sang ./dataset_1000/imgs
# Đã copy: 988e1511fa41388206e885300bfde2b7.jpg sang ./dataset_1000/imgs
# Đã copy: 5574d4b2a657cc3319e5b01adbd2d3e9.jpg sang ./dataset_1000/imgs
# Đã copy: 54f8d0b2da421f121b05b5161f650aef.jpg sang ./dataset_1000/imgs
# Đã copy: 03c0f79b356cef281b24d62c6798485a.jpg sang ./dataset_1000/imgs
# Đã copy: 4a83747a17f603ecaa90b48db9ea9b17.jpg sang ./dataset_1000/imgs
# Đã copy: 92046a19fd08f8d60d6fe7e5e97ca519.jpg sang ./dataset_1000/imgs
# Đã copy: 2042af03a1727115c53536ecae4209a8.jpg sang ./dataset_1000/imgs
# Đã copy: a496c78a814ed1dfea0659caee227732.jpg sang ./dataset_1000/imgs
# Đã copy: 027634251eacb8df2683138fb381ae8f.jpg sang ./dataset_1000/imgs
# Đã copy: df121f7ffb8958d82e0a6ca178e673be.jpg sang ./dataset_1000/imgs
# Đã copy: e70a24a6987f1ae4d693ae75ae02242e.jpg sang ./dataset_1000/imgs
# Đã copy: d083f701ef623b3b74fc6d2df61b75a3.jpg sang ./dataset_1000/imgs
# Đã copy: 4834a9e94bd246b5828e317accc9dd54.jpg sang ./dataset_1000/imgs
# Đã copy: 3132eb58accd2a071098081ad6e4a967.jpg sang ./dataset_1000/imgs
# Đã copy: c00c6f5d6fd890919061327dff18e937.jpg sang ./dataset_1000/imgs
# Đã copy: 9dd2aae9c484bd20d8ab15bd3dab926a.jpg sang ./dataset_1000/imgs
# Đã copy: e7068f958bc73bd37284db4301eaddc1.jpg sang ./dataset_1000/imgs
# Đã copy: bc5e09341db5fcba3e715fab15288f81.jpg sang ./dataset_1000/imgs
# Đã copy: d8425f914f433078370cc0a2f52b8970.jpg sang ./dataset_1000/imgs
# Đã copy: 53544f701cff0f27913c17b12bacce71.jpg sang ./dataset_1000/imgs
# Đã copy: e78a6e78a1696f1cf51eed7953b068d9.jpg sang ./dataset_1000/imgs
# Đã copy: 0194f4352a3c08a377a8437fca9d0bb5.jpg sang ./dataset_1000/imgs
# Đã copy: 5ab112de953b3afb417623fc1a378ac8.jpg sang ./dataset_1000/imgs
# Đã copy: f4eed19eaa6f1a5b7f3bf3fdab620193.jpg sang ./dataset_1000/imgs
# Đã copy: 4b1b4c36aae8795d9cbf087205edd9c9.jpg sang ./dataset_1000/imgs
# Đã copy: c1d2f3e7679731d99cedd43b073fb552.jpg sang ./dataset_1000/imgs
# Đã copy: 0ae2841eb6238bf9373589446b7886f6.jpg sang ./dataset_1000/imgs
# Đã copy: 65cb6a75832b8752f501fe6aa378c820.jpg sang ./dataset_1000/imgs
# Đã copy: 13fc7156a6f442b0d47b84a2d70ca19e.jpg sang ./dataset_1000/imgs
# Đã copy: 3fc8c7bf8d58543d12b654c415543115.jpg sang ./dataset_1000/imgs
# Đã copy: 6ca07b56e92f03ff469c64d08d39a9e9.jpg sang ./dataset_1000/imgs
# Đã copy: 2fbaaa04cdfb5e5228971b6a4bcac887.jpg sang ./dataset_1000/imgs
# Đã copy: 236b5c488814fda95359165a9fd564c8.jpg sang ./dataset_1000/imgs
# Đã copy: 325ef0995650a2bbbf5e04babfc7ebca.jpg sang ./dataset_1000/imgs
# Đã copy: c6838e6f126b5910953269ea82d9b46e.jpg sang ./dataset_1000/imgs
# Đã copy: fe19122a04e02fa4294e1bd362df4f4c.jpg sang ./dataset_1000/imgs
# Đã copy: 3f036c039e753c85eca1d28c7efd5c42.jpg sang ./dataset_1000/imgs
# Đã copy: c39fa2af8ee3250dc61893e57f004b2b.jpg sang ./dataset_1000/imgs
# Đã copy: a80cbc5e8bead1b9b3decb8387b081b0.jpg sang ./dataset_1000/imgs
# Đã copy: 0f2421786d043c7b0221be11f76aa21a.jpg sang ./dataset_1000/imgs
# Đã copy: 9abed18e16d7453bccb432811794dcad.jpg sang ./dataset_1000/imgs
# Đã copy: 02460361157b11a3c72badb8266ad0f5.jpg sang ./dataset_1000/imgs
# Đã copy: 5338745e9b279d577a26793e0574be80.jpg sang ./dataset_1000/imgs
# Đã copy: 541772f9b7bf2d7e91865ddf45ab3571.jpg sang ./dataset_1000/imgs
# Đã copy: a4a3a35581de0226159767b8e86a8734.jpg sang ./dataset_1000/imgs
# Đã copy: 8945f92993321c5a75b0c25bba0ae99b.jpg sang ./dataset_1000/imgs
# Đã copy: 81a76a217710df498c2047af45780e9c.jpg sang ./dataset_1000/imgs
# Đã copy: 5ac709f7aa8d6b70821586edb7e3dbd8.jpg sang ./dataset_1000/imgs
# Đã copy: 71cd7d0a7ef0fd80ba13f85a858f5425.jpg sang ./dataset_1000/imgs
# Đã copy: 3cbc71f1bcbc7a77f565360630dee9e9.jpg sang ./dataset_1000/imgs
# Đã copy: 257da5b2d621a784aa28210368f520a7.jpg sang ./dataset_1000/imgs
# Đã copy: 31bed2894d8f47c06be847b5e68c54d2.jpg sang ./dataset_1000/imgs
# Đã copy: 56ea7abc0a5205ab482d7bc9e1c98cf7.jpg sang ./dataset_1000/imgs
# Đã copy: 984527d050c0bd61ebc993d930774035.jpg sang ./dataset_1000/imgs
# Đã copy: 65752e9eea1087acf6a6a857c0fc8cd8.jpg sang ./dataset_1000/imgs
# Đã copy: 7102a8cfb5b385bfcaefa9b4c5138386.jpg sang ./dataset_1000/imgs
# Đã copy: dd508e39a061d510b52ef746d6f735f7.jpg sang ./dataset_1000/imgs
# Đã copy: 7a19bbef2f96972095052b319923d8ec.jpg sang ./dataset_1000/imgs
# Đã copy: 033160451ff201ad2de332ae311ce413.jpg sang ./dataset_1000/imgs
# Đã copy: 7fa64bea8d0e76d037958abcbe83d07a.jpg sang ./dataset_1000/imgs
# Đã copy: 0683db033b7041f9fd74e269b9febe30.jpg sang ./dataset_1000/imgs
# Đã copy: c112b76cb817475b5263586079228f39.jpg sang ./dataset_1000/imgs
# Đã copy: 3263a575ffe8b2fd66a15104e9a6f308.jpg sang ./dataset_1000/imgs
# Đã copy: f765e572fa1cbd731ff6b153e14dd147.jpg sang ./dataset_1000/imgs
# Đã copy: 9171c46ddf265e5d75d0a08c40dd5dee.jpg sang ./dataset_1000/imgs
# Đã copy: 64abe15d49b0d79551206ad1358dc8d5.jpg sang ./dataset_1000/imgs
# Đã copy: 19e5e2e71aabeeba91c18f726619849a.jpg sang ./dataset_1000/imgs
# Đã copy: dc776d98b6e44ee82cfef759953612c3.jpg sang ./dataset_1000/imgs
# Đã copy: 64c2306dcc78f1825a5b13be6e6bab0e.jpg sang ./dataset_1000/imgs
# Đã copy: 851aecc135bd276426121d70342bfbac.jpg sang ./dataset_1000/imgs
# Đã copy: 3a23c1f80b1db673259bc882d35d8436.jpg sang ./dataset_1000/imgs
# Đã copy: 2d5b691271a5727b048321ac88081762.jpg sang ./dataset_1000/imgs
# Đã copy: 973337c16398b719a429fe213b98290c.jpg sang ./dataset_1000/imgs
# Đã copy: 812fd0e1f0ebadf00c2d47f1655b18d8.jpg sang ./dataset_1000/imgs
# Đã copy: e442d545f821af8ab4ae01af4c1512d5.jpg sang ./dataset_1000/imgs
# Đã copy: bdbaac9d75a9b42a36bdbef3f5aa166c.jpg sang ./dataset_1000/imgs
# Đã copy: 87cb0cb2bf166081bf93c4ea23262cf4.jpg sang ./dataset_1000/imgs
# Đã copy: fb0d4362b78e446c10db020a43436637.jpg sang ./dataset_1000/imgs
# Đã copy: 478c5fbe2a200d550d7a27504dbd7c35.jpg sang ./dataset_1000/imgs
# Đã copy: 17cae35e12574e4995632ddd56fd5dc5.jpg sang ./dataset_1000/imgs
# Đã copy: 275872919804a45f6bf4499d1639d28f.jpg sang ./dataset_1000/imgs
# Đã copy: c5ad374fdef1cd50748cb4807183f208.jpg sang ./dataset_1000/imgs
# Đã copy: d97d311abb6f2e4333c99db2e898b7d8.jpg sang ./dataset_1000/imgs
# Đã copy: f425d57c29436bd2bf0bad31022636c4.jpg sang ./dataset_1000/imgs
# Đã copy: 0256f0f58771c19da0405fd12362c5fb.jpg sang ./dataset_1000/imgs
# Đã copy: 864d3e9e4cbcdafb6e21444aec4c17e4.jpg sang ./dataset_1000/imgs
# Đã copy: 0bc318aa3f12c592002742e34077b79f.jpg sang ./dataset_1000/imgs
# Đã copy: c28daec28ac9a74cd02fa9679732c17f.jpg sang ./dataset_1000/imgs
# Đã copy: 451bd3d03df9243d79bea6d2d1e1a25f.jpg sang ./dataset_1000/imgs
# Đã copy: 66fcec1ed69c6d23edee2c33e0a8846b.jpg sang ./dataset_1000/imgs
# Đã copy: 99ceb09f194d783d852b0261cf59fc99.jpg sang ./dataset_1000/imgs
# Đã copy: c64b0773307ad2628b5fe9bdd8337dab.jpg sang ./dataset_1000/imgs
# Đã copy: fc8e08863374d6502d9be8f6f2fa5474.jpg sang ./dataset_1000/imgs
# Đã copy: fa98e4d98ba21cbe4f69d99eddfeaa7f.jpg sang ./dataset_1000/imgs
# Đã copy: 8005a44978a52ed20c158aa50541e7f4.jpg sang ./dataset_1000/imgs
# Đã copy: c81c2d6f939d6249148fcdc5cc10df5a.jpg sang ./dataset_1000/imgs
# Đã copy: 9eafe4c4b2ceeb0b4ea3fefa2cc397b0.jpg sang ./dataset_1000/imgs
# Đã copy: e7e0b1d36e7c7a8313972471efa39383.jpg sang ./dataset_1000/imgs
# Đã copy: 704f13b8af56ed5e83693d1a11ed78be.jpg sang ./dataset_1000/imgs
# Đã copy: d07c929b5b3a3c9c09a581e27aa77295.jpg sang ./dataset_1000/imgs
# Đã copy: b8f8221eec14dc0dee8832720072608a.jpg sang ./dataset_1000/imgs
# Đã copy: 29a7212a7874abadb8b7394cea2d7818.jpg sang ./dataset_1000/imgs
# Đã copy: d62b399448691668f11a0123bc0ace83.jpg sang ./dataset_1000/imgs
# Đã copy: 8c1c4adda49edfd92217832c10e91757.jpg sang ./dataset_1000/imgs
# Đã copy: 50c0b9a595e38d3597145359620a86fd.jpg sang ./dataset_1000/imgs
# Đã copy: ce35b8496c3bb2c85089302e1651c23d.jpg sang ./dataset_1000/imgs
# Đã copy: 928ec9871ef19c7112858beac5369b8c.jpg sang ./dataset_1000/imgs
# Đã copy: f9eb43a4425c156c3bc6007a0ee77c32.jpg sang ./dataset_1000/imgs
# Đã copy: 405733761865840e49694790e70c38ec.jpg sang ./dataset_1000/imgs
# Đã copy: 43cebf4cc695630623317f844e9c60d5.jpg sang ./dataset_1000/imgs
# Đã copy: 0dd1f53b2c13dcc8eb86192fbd2a23fa.jpg sang ./dataset_1000/imgs
# Đã copy: f133ce24a265879aa286e1c1002ce780.jpg sang ./dataset_1000/imgs
# Đã copy: 09d6baf51ecf5909812cfab60b3f2b3a.jpg sang ./dataset_1000/imgs
# Đã copy: fe2441413104bba1f61a500010932168.jpg sang ./dataset_1000/imgs
# Đã copy: c6a7c087769a389d072c78a0f6471b35.jpg sang ./dataset_1000/imgs
# Đã copy: dc1443d349885e565492c17bdd08035e.jpg sang ./dataset_1000/imgs
# Đã copy: f8955634207f89528840460e5cf642d9.jpg sang ./dataset_1000/imgs
# Đã copy: 45855bea30a972c9a3fa8e81564cf8f2.jpg sang ./dataset_1000/imgs
# Đã copy: 41ebdb5b10b62cd024db711979cab784.jpg sang ./dataset_1000/imgs
# Đã copy: 72fe0e2aaa5db6ca594d41c203000e53.jpg sang ./dataset_1000/imgs
# Đã copy: c198ca1cfe590a3ddb4409d77d49ef4f.jpg sang ./dataset_1000/imgs
# Đã copy: 571ed813158b67367a66264ddc5d3723.jpg sang ./dataset_1000/imgs
# Đã copy: 65662dd682c30561df0d94a8aece29c1.jpg sang ./dataset_1000/imgs
# Đã copy: e825000821233b2be00c83549eea786a.jpg sang ./dataset_1000/imgs
# Đã copy: 4061b08f70a9147ca1d4a9c2bcd70a52.jpg sang ./dataset_1000/imgs
# Đã copy: a7c9b2fc543e45be6dd6ab790dbc300a.jpg sang ./dataset_1000/imgs
# Đã copy: fb7863480e907bd66354b8733ebf07f7.jpg sang ./dataset_1000/imgs
# Đã copy: 84a17e5af2adae711766ab4a2c845138.jpg sang ./dataset_1000/imgs
# Đã copy: 51d0a404b888128b51355816a6fd30d8.jpg sang ./dataset_1000/imgs
# Đã copy: 26cb4569bf016a16f308ea3804cfeada.jpg sang ./dataset_1000/imgs
# Đã copy: 0700dd53dbd1a09d11d0ff9c68dee23c.jpg sang ./dataset_1000/imgs
# Đã copy: 75d4322584ea5e98f5f400fc4efe1f4b.jpg sang ./dataset_1000/imgs
# Đã copy: 39fa48c0076c76dc52100daa5487d2f1.jpg sang ./dataset_1000/imgs
# Đã copy: f06eb7893da319aec3f0de768a1a845d.jpg sang ./dataset_1000/imgs
# Đã copy: adcf173aa19d021821f8009e6ea788ce.jpg sang ./dataset_1000/imgs
# Đã copy: f004a58f4c972d0de8347e0426f1de25.jpg sang ./dataset_1000/imgs
# Đã copy: fb0f8cb54c3bc6b56b1167d8cc8324d8.jpg sang ./dataset_1000/imgs
# Đã copy: c56d8e248e0fbcaaf8a729a8eedd6834.jpg sang ./dataset_1000/imgs
# Đã copy: 337a8b626cc31b5fec8b486c23cb898b.jpg sang ./dataset_1000/imgs
# Đã copy: 48357b24f8c48e657a19b412abf94ad5.jpg sang ./dataset_1000/imgs
# Đã copy: 19854260d3b289f83af20d576ddae844.jpg sang ./dataset_1000/imgs
# Đã copy: 04dc5c7b1878be1980c38813608ff95c.jpg sang ./dataset_1000/imgs
# Đã copy: d72bfddcd8a81833c2267af28469a0f0.jpg sang ./dataset_1000/imgs
# Đã copy: b0afe7228bf14c26b4608f174e762e15.jpg sang ./dataset_1000/imgs
# Đã tạo file JSON: ./dataset_1000/annotations\dress.json với 1000 phần tử.

# %% [markdown]
# # Tạo dữ liệu cho yolo

# %%
import os
import shutil
import json

# Đường dẫn đầu vào
train_input_path = "./8-labels-cloth-classification/train/data.json"
val_input_path = "./8-labels-cloth-classification/val/data.json"
test_input_path = "./8-labels-cloth-classification/test/data.json"
imgs_dir = "./8-labels-cloth-classification/imgs"

# Đường dẫn đầu ra
output_dirs = {
    "train": {"images": "./8-labels-cloth-classification/yolo/train/images/", "labels": "./8-labels-cloth-classification/yolo/train/labels/"},
    "val": {"images": "./8-labels-cloth-classification/yolo/val/images/", "labels": "./8-labels-cloth-classification/yolo/val/labels/"},
    "test": {"images": "./8-labels-cloth-classification/yolo/test/images/", "labels": "./8-labels-cloth-classification/yolo/test/labels/"},
}

# Hàm chuẩn hóa tọa độ bbox
def normalize_bbox(bbox, img_width, img_height):
    x_min, y_min, box_width, box_height = bbox
    x_center = (x_min + box_width / 2) / img_width
    y_center = (y_min + box_height / 2) / img_height
    width = box_width / img_width
    height = box_height / img_height
    return x_center, y_center, width, height

# Hàm xử lý dữ liệu
# Hàm xử lý dữ liệu với việc thêm các bộ đếm
def process_data(input_path, output_images_dir, output_labels_dir):
    with open(input_path, "r") as f:
        data = json.load(f)
    
    os.makedirs(output_images_dir, exist_ok=True)
    os.makedirs(output_labels_dir, exist_ok=True)

    num_images_copied = 0
    num_txt_files_created = 0

    for item in data:
        img_path = item["imgPath"]
        width, height = item["width"], item["height"]
        labels = item["bbox"]

        # Sao chép ảnh
        src_img_path = os.path.join(imgs_dir, img_path)
        dst_img_path = os.path.join(output_images_dir, img_path)
        shutil.copy(src_img_path, dst_img_path)
        num_images_copied += 1

        # Tạo file label
        label_file_path = os.path.join(output_labels_dir, os.path.splitext(img_path)[0] + ".txt")
        with open(label_file_path, "w") as label_file:
            for label in labels:
                class_id = label["label"]
                bbox = label["bbox"]
                normalized_bbox = normalize_bbox(bbox, width, height)
                label_file.write(f"{class_id} {' '.join(map(str, normalized_bbox))}\n")
            num_txt_files_created += 1

    print(f"Tệp input '{input_path}' có {len(data)} phần tử.")
    print(f"Đã sao chép {num_images_copied} ảnh vào '{output_images_dir}'.")
    print(f"Đã tạo {num_txt_files_created} tệp TXT vào '{output_labels_dir}'.")

# Xử lý từng tập dữ liệu
process_data(train_input_path, output_dirs["train"]["images"], output_dirs["train"]["labels"])
process_data(val_input_path, output_dirs["val"]["images"], output_dirs["val"]["labels"])
process_data(test_input_path, output_dirs["test"]["images"], output_dirs["test"]["labels"])

print("Chuyển đổi dữ liệu hoàn tất!")
# Out:
# Tệp input './8-labels-cloth-classification/train/data.json' có 35290 phần tử.
# Đã sao chép 35290 ảnh vào './8-labels-cloth-classification/yolo/train/images/'.
# Đã tạo 35290 tệp TXT vào './8-labels-cloth-classification/yolo/train/labels/'.
# Tệp input './8-labels-cloth-classification/val/data.json' có 4411 phần tử.
# Đã sao chép 4411 ảnh vào './8-labels-cloth-classification/yolo/val/images/'.
# Đã tạo 4411 tệp TXT vào './8-labels-cloth-classification/yolo/val/labels/'.
# Tệp input './8-labels-cloth-classification/test/data.json' có 4412 phần tử.
# Đã sao chép 4412 ảnh vào './8-labels-cloth-classification/yolo/test/images/'.
# Đã tạo 4412 tệp TXT vào './8-labels-cloth-classification/yolo/test/labels/'.
# Chuyển đổi dữ liệu hoàn tất!
